# %% [markdown]
#  # <center> Udacity Machine Learning Capstone Project: MLB Wins Prediction </center>
#  ## <center>John K. Hancock, August 2018</center>
#  ### <center>username: jkhancock@gmail.com</center>
#
#
#
# <center> <img src="mlb_logo.jpg" align="center" alt="Copyright Major League Baseball" height="320" width="320" /></center>

# %% [markdown]
# ## <center>MLB Wins Prediction</center>

# %% [markdown]
# ### <a id='Problem-Statement'><font color=black><u>Problem Statement</u></font></a>
# A new general manager ("GM") of a major league baseball team has been hired with the task of getting the team into the playoffs. The GM knows that to make the playoffs the team needs to have more wins than most other teams. In order to solve this problem, the GM wants to know what key performance statistics that his teams need to achieve in order to maximize the number of wins.
#
# The GM has tasked his Lead Data Scientist ("LDS") to build a model that can predict how many wins a team will have based on historical
# statistical data from winning teams and list the key statistical features that winning team can have. In
# the end, the GM will use this model to find players that fit these key statistical features. For example, if
# On-Base Percentage (“OBP”) shows that leads to more wins, the GM will look for players that have
# demonstrated high OBP.

# %% [markdown]
# ### <a id='Datasets-Inputs'><font color=black><u>Datasets and Inputs</u></font></a>
# Baseball has a long history of meticulous record keeping which laid the groundwork for data
# exploration and analysis, and there are several well established sources of data for this project. Perhaps the most comprehensive source is the website, FanGraphs.com (www.fangraphs.com).
#
# Fangraphs.com is website operated by FanGraphs, Inc. Fangraphs compiles historical statistical data for the entire history of Major League Baseball.  In addition, it creates and records advanced baseball metrics outside of the established statistics. FanGraphs is well established as a chronicler and compiler of baseball statistics.  It has parternership deals with ESPN and SB Nation. (Link to website: https://www.fangraphs.com/) (Wikipedia: https://en.wikipedia.org/wiki/Fangraphs)

# %% [markdown]
# ### <a id='Solution-Statement'><font color=black><u>Solution Statement</u></font></a>
# To predict wins, the Data Scientist will need to build a mapping function using historical team statistics for the past 20 years as input variables to predict the output variable (the number of wins). For this step, s/he will use the standard Linear Regression classification algorithm from Sci-kit Learn. Additionally, the Data Scientist will also use Deep Learning Neural Networks to perform Logistic Regression.

# %% [markdown]
# ### <a id='Project-Design'><font color=black><u>Project Design</u></font></a>
#
# #### <u> Part One: Data Collection and Data Wrangling </u>
#
# In part one, of this project, twenty years of all available MLB statistics were collected from the website, fangraphs.com.  The data was then explored, cleaned, and wrangled into a final datatset, "FINAL_DATASET_MLB_1998_to_2017.csv". Please see the notebook, <i><b>00_Capstone_Project_MLB_Collection_Wrangling</i></b>, located in the folder, 00_Data Collection and Wrangling for more details and explanations.
#
# #### <a id="home"><font color=black><u> Part Two: The Model </u></font></a>
# [0.0 The Final Dataset: Descriptive Statistics](#0.0)<br />
# [1.0 A Look at MLB Wins](#1.0)<br />
# [2.0 Separate the dependent variable from the independent variables](#2.0)<br />
# [3.0 Outliers](#3.0)<br />
# &nbsp; &nbsp; [3.1 Remove Outliers ](#3.1)<br />
# [4.0 Check for Skewness](#4.0)<br />
# [5.0 Pre-Processing data](#5.0)<br />
#  &nbsp; &nbsp; [5.1 Select The Best Features](#5.1)<br />
#   &nbsp; &nbsp; [5.2 Split the Dataset](#5.2)<br />
# [6.0 Model One: LASSO Regression](#6.0)<br />
# [7.0 Model Two: Linear Regression with Deep Neural Network](#7.0)<br />
# [8.0 Cluster Segment Analysis](#8.0)<br />
# [9.0 Final Summary ](#9.0)<br />
# [10.0 Project Reflections ](#10.0)<br />
# [11.0 References](#11.0)<br />

# %% [markdown]
# #### <a id='0.0'><font color=black><u>0.0 The Final Dataset: Descriptive Statistics</u></font></a>

# %%
import warnings
warnings.simplefilter('ignore')

import collections
import numpy as np
import os
import pandas as pd
import pprint as pp
import visuals as vs
import capstoneutils as hp

from glob import glob
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LassoLarsCV
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
path = os.getcwd()

import matplotlib.pyplot as plt
# Pretty display for notebooks
# %matplotlib inline
# Out:
# C:\Users\jkhan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
Final_MLB_Data = pd.DataFrame()
Final_MLB_Data = pd.read_csv(path +r'\FINAL DATASET version 1.0\FINAL_DATASET_MLB_1998_to_2017.csv', index_col=0)
print ("The baseball dataset has {} data points with {} variables each.".format(*Final_MLB_Data.shape))
# Out:
# The baseball dataset has 600 data points with 67 variables each.

# %%
print("Summary fielding statistics are below:")
Final_MLB_Data[['FIELD_E', 'FIELD_DP', 'FIELD_SB', 'FIELD_CS', 'FIELD_PB',
       'FIELD_WP', 'FIELD_FP', 'FIELD_PO']].describe()
# Out:
# Summary fielding statistics are below:
#           FIELD_E    FIELD_DP    FIELD_SB    FIELD_CS    FIELD_PB    FIELD_WP  \
# count  600.000000  600.000000  600.000000  600.000000  600.000000  600.000000
# mean   102.468333  368.035000   95.260000   38.640000   11.141667   53.286667
# std     16.984988   52.459067   25.103573    9.927302    4.990301   12.850800
# min     54.000000  216.000000   32.000000   14.000000    2.000000   22.000000
# 25%     90.000000  333.000000   77.000000   31.750000    8.000000   44.000000
# 50%    102.000000  365.000000   94.000000   38.000000   10.000000   52.000000
# 75%    113.000000  399.000000  110.000000   44.000000   13.250000   61.000000
# max    160.000000  557.000000  223.000000   75.000000   37.000000   98.000000
#
#          FIELD_FP     FIELD_PO
# count  600.000000   600.000000
# mean     0.983183  4335.656667
# std      0.002745    39.980072
# min      0.974000  4235.000000
# 25%      0.982000  4308.000000
# 50%      0.983000  4333.500000
# 75%      0.985000  4360.000000
# max      0.991000  4485.000000

# %%
print("Summary hitting statistics are below:")
Final_MLB_Data[['OFF_PA', 'OFF_HR', 'OFF_R',
       'OFF_RBI', 'OFF_SB', 'OFF_ISO', 'OFF_BABIP', 'OFF_AVG', 'OFF_OBP',
       'OFF_SLG', 'OFF_wOBA', 'OFF_wRC+', 'OFF_H', 'OFF_1B', 'OFF_2B',
       'OFF_3B', 'OFF_BB', 'OFF_IBB', 'OFF_SO', 'OFF_HBP', 'OFF_SF',
       'OFF_GDP', 'OFF_CS', 'OFF_BB%', 'OFF_K%', 'OFF_BB/K']].describe()
# Out:
# Summary hitting statistics are below:
#             OFF_PA      OFF_HR        OFF_R     OFF_RBI      OFF_SB  \
# count   600.000000  600.000000   600.000000  600.000000  600.000000
# mean   6221.368333  170.516667   745.493333  709.658333   95.260000
# std     118.249119   34.605042    85.025244   82.469451   30.878659
# min    5905.000000   91.000000   513.000000  485.000000   19.000000
# 25%    6137.750000  147.000000   686.000000  654.000000   71.000000
# 50%    6216.000000  167.000000   739.000000  705.000000   92.000000
# 75%    6302.250000  196.250000   804.000000  763.500000  116.000000
# max    6554.000000  260.000000  1009.000000  960.000000  200.000000
#
#           OFF_ISO   OFF_BABIP     OFF_AVG     OFF_OBP    OFF_SLG     ...      \
# count  600.000000  600.000000  600.000000  600.000000  600.00000     ...
# mean     0.155033    0.298123    0.261303    0.329028    0.41633     ...
# std      0.019416    0.010751    0.012101    0.014713    0.02669     ...
# min      0.104000    0.269000    0.226000    0.292000    0.33500     ...
# 25%      0.140000    0.291000    0.253000    0.319000    0.39700     ...
# 50%      0.154000    0.298000    0.261000    0.329000    0.41600     ...
# 75%      0.170000    0.305000    0.270000    0.339000    0.43400     ...
# max      0.206000    0.332000    0.294000    0.373000    0.49100     ...
#
#            OFF_BB     OFF_IBB       OFF_SO     OFF_HBP      OFF_SF  \
# count  600.000000  600.000000   600.000000  600.000000  600.000000
# mean   526.641667   39.521667  1129.445000   55.843333   44.493333
# std     73.435240   14.180080   143.103079   13.567692    8.800134
# min    363.000000   12.000000   805.000000   26.000000   24.000000
# 25%    473.000000   30.000000  1028.000000   46.000000   38.000000
# 50%    523.500000   38.000000  1113.500000   54.000000   44.000000
# 75%    572.250000   47.000000  1226.000000   64.000000   50.000000
# max    775.000000  153.000000  1571.000000  103.000000   75.000000
#
#           OFF_GDP      OFF_CS     OFF_BB%      OFF_K%    OFF_BB/K
# count  600.000000  600.000000  600.000000  600.000000  600.000000
# mean   125.981667   38.640000    0.084520    0.181733    0.474083
# std     15.405092   11.522225    0.010601    0.024331    0.090189
# min     82.000000   12.000000    0.061000    0.127000    0.280000
# 25%    115.000000   31.000000    0.077000    0.164000    0.400000
# 50%    126.000000   38.000000    0.084000    0.178500    0.470000
# 75%    137.000000   46.000000    0.091000    0.198000    0.530000
# max    170.000000   81.000000    0.120000    0.256000    0.810000
#
# [8 rows x 26 columns]

# %%
print("Summary pitching statistics are below:")
Final_MLB_Data[['PITCH_ERA', 'PITCH_CG', 'PITCH_ShO', 'PITCH_SV', 'PITCH_H',
       'PITCH_R', 'PITCH_ER', 'PITCH_HR', 'PITCH_BB', 'PITCH_IBB',
       'PITCH_HBP', 'PITCH_WP', 'PITCH_BK', 'PITCH_SO', 'PITCH_K/9',
       'PITCH_BB/9', 'PITCH_K/BB', 'PITCH_H/9', 'PITCH_HR/9', 'PITCH_AVG',
       'PITCH_WHIP', 'PITCH_BABIP', 'PITCH_LOB%', 'PITCH_FIP',
       'PITCH_Starting', 'PITCH_Relieving', 'PITCH_Start-IP',
       'PITCH_Relief-IP', 'PITCH_K%', 'PITCH_BB%', 'PITCH_Age']].describe()
# Out:
# Summary pitching statistics are below:
#         PITCH_ERA    PITCH_CG   PITCH_ShO    PITCH_SV      PITCH_H  \
# count  600.000000  600.000000  600.000000  600.000000   600.000000
# mean     4.280083    5.386667    2.106667   40.910000  1449.163333
# std      0.541783    3.681904    1.671310    7.290896    91.121999
# min      2.940000    0.000000    0.000000   23.000000  1125.000000
# 25%      3.890000    3.000000    1.000000   36.000000  1385.750000
# 50%      4.240000    5.000000    2.000000   41.000000  1448.500000
# 75%      4.660000    7.000000    3.000000   46.000000  1509.000000
# max      6.030000   24.000000   14.000000   66.000000  1700.000000
#
#            PITCH_R    PITCH_ER    PITCH_HR    PITCH_BB   PITCH_IBB  \
# count   600.000000  600.000000  600.000000  600.000000  600.000000
# mean    745.486667  686.883333  170.516667  526.638333   39.521667
# std      90.149217   83.669712   26.434909   67.425746   15.029616
# min     525.000000  478.000000   96.000000  348.000000    8.000000
# 25%     680.000000  627.000000  152.000000  478.000000   29.000000
# 50%     742.000000  682.000000  169.000000  524.000000   37.000000
# 75%     812.000000  747.000000  187.250000  572.000000   48.000000
# max    1028.000000  957.000000  258.000000  737.000000  107.000000
#
#           ...      PITCH_BABIP  PITCH_LOB%   PITCH_FIP  PITCH_Starting  \
# count     ...       600.000000  600.000000  600.000000      600.000000
# mean      ...         0.294540    0.718550    4.279350      111.085667
# std       ...         0.010619    0.023334    0.431588       39.713459
# min       ...         0.255000    0.657000    3.180000        8.200000
# 25%       ...         0.287000    0.702750    3.970000       83.100000
# 50%       ...         0.294000    0.718000    4.280000      111.750000
# 75%       ...         0.302000    0.736000    4.570000      136.225000
# max       ...         0.331000    0.794000    5.540000      231.500000
#
#        PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP    PITCH_K%  \
# count       600.000000      600.000000       600.000000  600.000000
# mean         26.974000      948.600667       490.389667    0.181878
# std          21.676148       45.854687        42.291812    0.024442
# min         -50.600000      760.800000       361.200000    0.120000
# 25%          12.400000      918.300000       461.125000    0.164000
# 50%          26.800000      952.400000       489.750000    0.180000
# 75%          42.200000      980.100000       518.125000    0.196250
# max          94.100000     1072.800000       652.100000    0.275000
#
#         PITCH_BB%   PITCH_Age
# count  600.000000  600.000000
# mean     0.084578   28.093333
# std      0.009696    1.176263
# min      0.057000   25.000000
# 25%      0.078000   27.000000
# 50%      0.084500   28.000000
# 75%      0.091000   29.000000
# max      0.112000   32.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# <font color=black><u><b>The Pythagorean Theorem of Baseball</b></u></font><br />
# The Pythagorean Theorem of Baseball is a creation of Bill James which relates the number of runs a team has scored and surrendered to its actual winning percentage, based on the idea that runs scored compared to runs allowed is a better indicator of a team's (future) performance than a team's actual winning percentage. This results in a formula which is referred to as Pythagorean Winning Percentage. (Baseball Reference.com https://www.baseball-reference.com/bullpen/Pythagorean_Theorem_of_Baseball)<br />
#
# The formula is "1 / (1 + (Runs Allowed / Runs Scored)^2)". The results below show that even with this traditional wins prediction heuristic there is variance between what the formula predicts and the actual results.

# %%
 #Baseball's Pythagorean Thereom 1 / (1 + (Runs Allowed / Runs Scored)**2)

min_runs_allowed = Final_MLB_Data['PITCH_R'].min()
runs_scored = Final_MLB_Data.loc[Final_MLB_Data['PITCH_R'] == min_runs_allowed]['OFF_R'].item()
win_total = Final_MLB_Data.loc[Final_MLB_Data['PITCH_R'] == min_runs_allowed]['W'].item()
pythag1 =  float(1 / (1 + (min_runs_allowed/runs_scored)**2))
expected_wins1 = 162*pythag1

max_runs_scored = Final_MLB_Data['OFF_R'].max()
runs_allowed = Final_MLB_Data.loc[Final_MLB_Data['OFF_R'] == max_runs_scored]['PITCH_R'].item()
win_total2 = Final_MLB_Data.loc[Final_MLB_Data['OFF_R'] == max_runs_scored]['W'].item()
pythag2 = float(1 / (1 + (runs_allowed/max_runs_scored)**2))
expected_wins2 = 162*pythag2

    
    
print("The minimum number of runs allowed by a team over the past 20 years is %.0f and that team's win total was %.0f." % (min_runs_allowed, win_total))
print("That same team scored %.0f runs for a run differential of %.0f" % (runs_scored, runs_scored-min_runs_allowed))
print("According to the Pythagorean Theorem of Baseball, the team's win total should have been %.2f" % expected_wins1)
print("\n")
print("The maximum number of runs scored by a team over the past 20 years is %.0f and that team's win total was %.0f." % (max_runs_scored, win_total2))
print("That same team allowed %.0f runs for a run differential of %.0f" % (runs_allowed, max_runs_scored-runs_allowed))
print("According to the Pythagorean Theorem of Baseball, the team's win total should have been %.2f" % expected_wins2)
# Out:
# The minimum number of runs allowed by a team over the past 20 years is 525 and that team's win total was 100.
# That same team scored 891 runs for a run differential of 366
# According to the Pythagorean Theorem of Baseball, the team's win total should have been 120.25
#
#
# The maximum number of runs scored by a team over the past 20 years is 1009 and that team's win total was 103.
# That same team allowed 661 runs for a run differential of 348
# According to the Pythagorean Theorem of Baseball, the team's win total should have been 113.35

# %% [markdown]
# #### <a id='1.0'><font color=black><u>1.0 A Look at MLB Wins </u></font></a>
#
# The objective of this project is to build a model that can predict the number of wins and lists the most important features that are important to winning. Over the past 20 year, the average and median number of wins is 81 games, and the standard deviation is 11.52. In order to make the playoffs, the team needs to win at least one full standard deviation above the mean or 93 wins.

# %%
text = "Median No. of Wins is %.0f" % Final_MLB_Data['W'].median()

Final_MLB_Data['W'].plot.hist(grid=True, bins=40, rwidth=0.9,color='green')
plt.title('MLB Team Wins')
plt.xlabel('Wins')
plt.ylabel('Number of seasons')
plt.text(41,40,text)
plt.grid(axis='y', alpha=0.75)

# %%
print("The average number of wins %.0f." % Final_MLB_Data['W'].mean())
print("The median number of wins %.2f." % Final_MLB_Data['W'].median())
print("The standard deviation for wins is %.2f." % Final_MLB_Data['W'].std())
# Out:
# The average number of wins 81.
# The median number of wins 81.00.
# The standard deviation for wins is 11.52.

# %%
text = "Total number is %d or %.2f%%" % (Final_MLB_Data.loc[Final_MLB_Data['W'] >= 93, ['W']].count(), float((Final_MLB_Data.loc[Final_MLB_Data['W'] >= 93, ['W']].count())/(Final_MLB_Data['W'].count()))*100)

Final_MLB_Data.loc[Final_MLB_Data['W'] >= 93, ['W']].plot.hist(grid=True, bins=40, rwidth=0.9,color='blue')
plt.title('Seasons an MLB Team Won 93 or more Games')
plt.xlabel('Wins')
plt.ylabel('Number of seasons')
plt.text(98,17.5,text)
plt.grid(axis='y', alpha=0.55)
plt.grid(axis='x', alpha=0.35)

# %%
text = "Total number is %d or %.2f%%" % (Final_MLB_Data.loc[Final_MLB_Data['W'] >= 95, ['W']].count(), float((Final_MLB_Data.loc[Final_MLB_Data['W'] >= 95, ['W']].count())/(Final_MLB_Data['W'].count()))*100)

Final_MLB_Data.loc[Final_MLB_Data['W'] >= 95, ['W']].plot.hist(grid=True, bins=40, rwidth=0.9,color='orange')
plt.title('Seasons MLB Team Won 95 or more Games')
plt.xlabel('Wins')
plt.ylabel('Number of seasons')
plt.text(98,17.5,text)
plt.grid(axis='y', alpha=0.55)
plt.grid(axis='x', alpha=0.35)

# %%
text = "Total number is %d or %.2f%%" % (Final_MLB_Data.loc[Final_MLB_Data['W'] >= 100, ['W']].count(), float((Final_MLB_Data.loc[Final_MLB_Data['W'] >= 100, ['W']].count())/(Final_MLB_Data['W'].count()))*100)

Final_MLB_Data.loc[Final_MLB_Data['W'] >= 100, ['W']].plot.hist(grid=True, bins=40, rwidth=0.9,color='red')
plt.title('Seasons MLB Team Won 100 or more Games')
plt.xlabel('Wins')
plt.ylabel('Number of seasons')
plt.text(104,3.5,text)
plt.grid(axis='y', alpha=0.55)
plt.grid(axis='x', alpha=0.35)

# %%
prob_93 = (Final_MLB_Data.loc[Final_MLB_Data['W'] >= 93, ['W']].count())/(Final_MLB_Data['W'].count())*100
prob_95 = (Final_MLB_Data.loc[Final_MLB_Data['W'] >= 95, ['W']].count())/(Final_MLB_Data['W'].count())*100
prob_100 = (Final_MLB_Data.loc[Final_MLB_Data['W'] >= 100, ['W']].count())/(Final_MLB_Data['W'].count())*100
print("To summarize:")
print("The probabilty of winning 93 or more games is %.2f%%." % prob_93 )
print("The probabilty of winning 95 or more games is %.2f%%." % prob_95 )
print("The probabilty of winning 100 or more games is %.2f%%." % prob_100 )
# Out:
# To summarize:
# The probabilty of winning 93 or more games is 18.67%.
# The probabilty of winning 95 or more games is 13.83%.
# The probabilty of winning 100 or more games is 4.00%.

# %% [markdown]
# #### <a id='1.0'><font color=black><u>1.1 Dataset information </u></font></a>
#
# By looking at the shape, describing the data, and the information for the data, we see that all of the variables are continuous data, not categorical.  For the purpose of this project, we won't need to convert any column, e.g. one-hot-encoding.

# %%
Final_MLB_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 0 to 599
# Data columns (total 67 columns):
# FIELD_E            600 non-null int64
# FIELD_DP           600 non-null int64
# FIELD_SB           600 non-null int64
# FIELD_CS           600 non-null int64
# FIELD_PB           600 non-null int64
# FIELD_WP           600 non-null int64
# FIELD_FP           600 non-null float64
# FIELD_PO           600 non-null int64
# OFF_PA             600 non-null int64
# OFF_HR             600 non-null int64
# OFF_R              600 non-null int64
# OFF_RBI            600 non-null int64
# OFF_SB             600 non-null int64
# OFF_ISO            600 non-null float64
# OFF_BABIP          600 non-null float64
# OFF_AVG            600 non-null float64
# OFF_OBP            600 non-null float64
# OFF_SLG            600 non-null float64
# OFF_wOBA           600 non-null float64
# OFF_wRC+           600 non-null int64
# OFF_H              600 non-null int64
# OFF_1B             600 non-null int64
# OFF_2B             600 non-null int64
# OFF_3B             600 non-null int64
# OFF_BB             600 non-null int64
# OFF_IBB            600 non-null int64
# OFF_SO             600 non-null int64
# OFF_HBP            600 non-null int64
# OFF_SF             600 non-null int64
# OFF_GDP            600 non-null int64
# OFF_CS             600 non-null int64
# OFF_BB%            600 non-null float64
# OFF_K%             600 non-null float64
# OFF_BB/K           600 non-null float64
# W                  600 non-null int64
# L                  600 non-null int64
# PITCH_ERA          600 non-null float64
# PITCH_CG           600 non-null int64
# PITCH_ShO          600 non-null int64
# PITCH_SV           600 non-null int64
# PITCH_H            600 non-null int64
# PITCH_R            600 non-null int64
# PITCH_ER           600 non-null int64
# PITCH_HR           600 non-null int64
# PITCH_BB           600 non-null int64
# PITCH_IBB          600 non-null int64
# PITCH_HBP          600 non-null int64
# PITCH_WP           600 non-null int64
# PITCH_BK           600 non-null int64
# PITCH_SO           600 non-null int64
# PITCH_K/9          600 non-null float64
# PITCH_BB/9         600 non-null float64
# PITCH_K/BB         600 non-null float64
# PITCH_H/9          600 non-null float64
# PITCH_HR/9         600 non-null float64
# PITCH_AVG          600 non-null float64
# PITCH_WHIP         600 non-null float64
# PITCH_BABIP        600 non-null float64
# PITCH_LOB%         600 non-null float64
# PITCH_FIP          600 non-null float64
# PITCH_Starting     600 non-null float64
# PITCH_Relieving    600 non-null float64
# PITCH_Start-IP     600 non-null float64
# PITCH_Relief-IP    600 non-null float64
# PITCH_K%           600 non-null float64
# PITCH_BB%          600 non-null float64
# PITCH_Age          600 non-null int64
# dtypes: float64(27), int64(40)
# memory usage: 318.8 KB

# %% [markdown]
# #### <a id='2.0'><font color=black><u>2.0 Separate the indepenedent and dependent variables </u></font></a>

# %%
#Create the predictor variables by first dropping the "L" column
Final_MLB_Data= Final_MLB_Data.drop("L", axis=1)
#Create the target variable Wins
Wins = Final_MLB_Data["W"]
#Remove the target from the features
features = Final_MLB_Data.drop("W", axis=1)

# %% [markdown]
# #### <a id='3.0'><font color=black><u>3.0 Remove Outliers </u></font></a>
#
# In this section, outliers in the dataset are identified and removed.  "Tukey's Method for identfying outliers: An outlier step is calculated as 1.5 times the interquartile range (IQR). A data point with a feature that is beyond an outlier step outside of the IQR for that feature is considered abnormal." (citation: Udacity MLND course on Unsupervised Learning. Customer Segments project.)(Turkey's Method: http://datapigtechnologies.com/blog/index.php/highlighting-outliers-in-your-data-with-the-tukey-method/)
#
# (See the function: detect_outliers in capstoneutils.py)

# %%
cnt = hp.detect_outliers(features)
outliers  = [list(cnt.keys())]
# Out:
# Data points considered outliers for the feature 'FIELD_E':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 23       155       334       132        64        18        50     0.975
# 53       160       335       157        47        16        46     0.974
# 451       54       428        63        32         8        38     0.991
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 23       4280    6300     126    ...            0.300       0.687       4.81
# 53       4303    6234     171    ...            0.313       0.687       4.60
# 451      4359    6388     176    ...            0.291       0.755       3.45
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 23            114.1             17.8           950.8            491.1
# 53            119.6             74.0           911.6            520.3
# 451           143.9             30.7           977.6            467.6
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 23      0.150      0.094         27
# 53      0.155      0.081         29
# 451     0.214      0.076         29
#
# [3 rows x 65 columns]
# Data points considered outliers for the feature 'FIELD_DP':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 18       102       517       108        52         9        47     0.984
# 22       110       517       125        34        14        48     0.982
# 31        89       508        93        50         5        55     0.986
# 36       125       504       111        49        10        60     0.980
# 41       135       541       101        69        12        52     0.978
# 48       118       512       163        63         9        70     0.981
# 63       133       503        79        58        13        43     0.978
# 82       118       503        86        58        12        60     0.981
# 96       117       557       105        45        10        73     0.981
# 223      100       500        32        33        12        41     0.984
# 443      121       216       152        47        18        49     0.980
# 489       88       221        82        26         9        65     0.985
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 18       4297    6243     165    ...            0.282       0.683       4.69
# 22       4353    6263     115    ...            0.298       0.674       4.70
# 31       4305    6389     230    ...            0.284       0.752       4.27
# 36       4262    6454     181    ...            0.285       0.736       4.39
# 41       4299    6310     244    ...            0.290       0.709       4.84
# 48       4286    6264     162    ...            0.303       0.708       5.06
# 63       4351    6410     216    ...            0.297       0.719       4.38
# 82       4399    6153     178    ...            0.314       0.691       4.76
# 96       4320    6385     199    ...            0.300       0.715       3.79
# 223      4337    6214     128    ...            0.308       0.704       3.81
# 443      4304    6091     139    ...            0.291       0.713       4.46
# 489      4391    6222     142    ...            0.282       0.727       3.58
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 18             86.1              1.3           997.6            428.2
# 22             89.5             31.7           984.7            444.4
# 31            189.1             28.0          1054.8            406.7
# 36            118.0             48.8           962.6            488.0
# 41             78.3             26.1           967.0            483.5
# 48             87.5             33.1           930.1            501.7
# 63            123.8             49.0          1012.6            428.0
# 82            102.3             37.0           918.0            509.3
# 96            171.9             77.7           971.3            472.8
# 223           181.5             17.7           965.7            470.8
# 443            64.0            -22.9           919.4            485.4
# 489            90.7             12.4           974.9            469.2
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 18      0.148      0.080         27
# 22      0.146      0.084         29
# 31      0.192      0.087         29
# 36      0.188      0.099         30
# 41      0.167      0.102         29
# 48      0.150      0.092         25
# 63      0.172      0.099         29
# 82      0.165      0.081         26
# 96      0.205      0.075         29
# 223     0.180      0.090         29
# 443     0.184      0.093         28
# 489     0.204      0.065         30
#
# [12 rows x 65 columns]
# Data points considered outliers for the feature 'FIELD_SB':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 1         81       394       182        53        12        51     0.987
# 48       118       512       163        63         9        70     0.981
# 52       127       397       177        44        13        64     0.979
# 92       113       342       223        51        23        54     0.981
# 299       92       352       189        20         9        42     0.985
# 324       85       349       168        38        11        43     0.986
# 387      111       327       169        42        14        58     0.982
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 1        4293    6401     201    ...            0.295       0.761       3.86
# 48       4286    6264     162    ...            0.303       0.708       5.06
# 52       4328    6272     145    ...            0.320       0.686       4.84
# 92       4344    6474     169    ...            0.283       0.745       3.96
# 299      4454    6213     131    ...            0.331       0.668       4.70
# 324      4375    6118     120    ...            0.307       0.707       4.59
# 387      4370    5974     126    ...            0.296       0.701       4.76
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 1             151.2             27.5          1057.7            409.9
# 48             87.5             33.1           930.1            501.7
# 52             93.9             45.9           874.8            551.9
# 92            169.7             37.9          1006.5            437.8
# 299           121.8            -32.3           930.8            492.8
# 324            61.2             15.1           902.2            525.9
# 387            62.8            -32.7           991.6            435.5
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 1       0.191      0.075         27
# 48      0.150      0.092         25
# 52      0.163      0.107         28
# 92      0.186      0.082         29
# 299     0.187      0.089         27
# 324     0.160      0.098         28
# 387     0.171      0.088         28
#
# [7 rows x 65 columns]
# Data points considered outliers for the feature 'FIELD_CS':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 0        106       392       156        65        29        70     0.983
# 5        115       452       120        69        14        60     0.982
# 14       100       345        93        63         9        52     0.984
# 23       155       334       132        64        18        50     0.975
# 24       101       395       117        64         9        40     0.984
# 41       135       541       101        69        12        52     0.978
# 44       104       356       138        66        17        39     0.983
# 48       118       512       163        63         9        70     0.981
# 49       127       404        94        67        10        46     0.979
# 57       132       420        80        69         8        60     0.978
# 87       111       391        70        66         8        49     0.981
# 102      114       468        79        66         2        70     0.981
# 152      118       399       117        75         8        50     0.981
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 0        4329    6444     207    ...            0.285       0.744       3.53
# 5        4340    6304     214    ...            0.277       0.738       4.15
# 14       4296    6280     147    ...            0.303       0.722       4.54
# 23       4280    6300     126    ...            0.300       0.687       4.81
# 24       4374    6157     111    ...            0.308       0.685       4.54
# 41       4299    6310     244    ...            0.290       0.709       4.84
# 44       4403    6325     151    ...            0.290       0.715       5.01
# 48       4286    6264     162    ...            0.303       0.708       5.06
# 49       4307    6096     212    ...            0.306       0.694       4.77
# 57       4336    6216     128    ...            0.304       0.673       4.94
# 87       4301    6291     157    ...            0.303       0.680       5.14
# 102      4315    6233     203    ...            0.286       0.718       4.26
# 152      4371    6431     230    ...            0.278       0.744       4.09
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 0             230.9             24.8          1072.8            361.2
# 5             184.2             28.2          1059.7            392.3
# 14            120.2             40.3          1003.7            452.1
# 23            114.1             17.8           950.8            491.1
# 24            144.8             12.6           991.3            425.1
# 41             78.3             26.1           967.0            483.5
# 44            119.6              1.0           991.0            439.1
# 48             87.5             33.1           930.1            501.7
# 49            129.3             18.3           964.5            470.3
# 57            104.7             -8.3           933.0            491.6
# 87             90.7              1.2           986.6            445.7
# 102           149.4             12.5           991.0            452.9
# 152           108.1             41.4           947.1            485.8
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 0       0.207      0.078         29
# 5       0.177      0.076         28
# 14      0.162      0.088         30
# 23      0.150      0.094         27
# 24      0.184      0.084         30
# 41      0.167      0.102         29
# 44      0.157      0.103         30
# 48      0.150      0.092         25
# 49      0.158      0.090         27
# 57      0.154      0.083         29
# 87      0.165      0.093         29
# 102     0.196      0.085         31
# 152     0.165      0.090         28
#
# [13 rows x 65 columns]
# Data points considered outliers for the feature 'FIELD_PB':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 0        106       392       156        65        29        70     0.983
# 2        105       337       132        58        35        62     0.983
# 32       127       346       159        58        31        28     0.979
# 62       109       320       159        47        26        33     0.982
# 92       113       342       223        51        23        54     0.981
# 95       131       447       104        50        30        40     0.979
# 127       90       407       103        44        22        54     0.985
# 132      120       392        67        42        28        52     0.981
# 149      142       334        72        34        23        59     0.977
# 265       66       414       108        23        24        52     0.989
# 395       92       271       156        50        32        58     0.985
# 419      116       303       121        33        26        46     0.981
# 446      101       330        97        30        32        40     0.983
# 447      122       338       121        43        22        94     0.980
# 474      111       365        87        29        30        54     0.982
# 513       88       355        60        41        25        62     0.985
# 526       97       359        75        38        22        79     0.984
# 538      101       377        75        30        22        61     0.983
# 541       76       332        59        33        37        52     0.987
# 553       88       360        84        20        29        50     0.986
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 0        4329    6444     207    ...            0.285       0.744       3.53
# 2        4307    6331     234    ...            0.293       0.747       3.84
# 32       4310    6416     193    ...            0.312       0.728       3.69
# 62       4358    6418     226    ...            0.286       0.718       4.31
# 92       4344    6474     169    ...            0.283       0.745       3.96
# 95       4288    6408     235    ...            0.294       0.727       3.91
# 127      4352    6318     165    ...            0.293       0.707       3.62
# 132      4360    6246     175    ...            0.284       0.730       4.11
# 149      4241    5920     124    ...            0.296       0.688       5.11
# 265      4324    6326     174    ...            0.297       0.674       4.39
# 395      4372    6113     185    ...            0.282       0.745       3.89
# 419      4344    5972     109    ...            0.302       0.695       4.67
# 446      4302    6057     137    ...            0.296       0.696       4.41
# 447      4266    5967     137    ...            0.294       0.689       4.66
# 474      4356    6122     146    ...            0.293       0.723       4.30
# 513      4323    6268     212    ...            0.288       0.743       3.53
# 526      4345    6131     198    ...            0.294       0.737       4.21
# 538      4358    6019     148    ...            0.316       0.711       4.40
# 541      4319    6236     204    ...            0.288       0.750       3.58
# 553      4378    6245     200    ...            0.298       0.740       4.27
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 0             230.9             24.8          1072.8            361.2
# 2             166.8             35.3          1031.1            416.8
# 32            219.1             51.6          1054.5            400.2
# 62            177.9             18.7          1001.0            444.1
# 92            169.7             37.9          1006.5            437.8
# 95            169.6             50.9           970.7            460.7
# 127           212.6             61.0          1022.1            425.0
# 132           123.4             58.8           996.0            443.5
# 149            53.5            -27.3           975.8            459.4
# 265           160.0              0.6           960.1            456.7
# 395           143.2              2.0          1039.5            419.2
# 419            40.1             16.7           877.5            561.7
# 446            46.0             20.3           926.0            511.4
# 447            17.7             15.6           877.2            556.1
# 474            53.9             36.8           895.6            548.0
# 513           153.7             31.9          1000.8            454.4
# 526            59.3             22.4           883.6            574.9
# 538            42.3             31.4           889.4            539.7
# 541           168.1             49.1           957.9            495.7
# 553           113.4             33.3           974.2            465.0
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 0       0.207      0.078         29
# 2       0.198      0.082         29
# 32      0.194      0.077         27
# 62      0.186      0.092         29
# 92      0.186      0.082         29
# 95      0.218      0.089         28
# 127     0.184      0.065         30
# 132     0.174      0.072         29
# 149     0.144      0.097         26
# 265     0.184      0.083         28
# 395     0.173      0.078         28
# 419     0.165      0.085         28
# 446     0.189      0.085         29
# 447     0.152      0.075         28
# 474     0.193      0.080         30
# 513     0.221      0.063         28
# 526     0.194      0.080         26
# 538     0.182      0.077         28
# 541     0.245      0.078         28
# 553     0.205      0.084         28
#
# [20 rows x 65 columns]
# Data points considered outliers for the feature 'FIELD_WP':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 77       111       420        81        33        12        96     0.982
# 359      116       365       114        39        14        89     0.981
# 447      122       338       121        43        22        94     0.980
# 549       77       315        67        31        18        98     0.987
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 77       4369    6238     184    ...            0.312       0.710       4.48
# 359      4278    6057     122    ...            0.307       0.703       5.03
# 447      4266    5967     137    ...            0.294       0.689       4.66
# 549      4404    6089     215    ...            0.303       0.740       3.97
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 77            153.7             61.6           907.8            528.0
# 359            56.0             18.0           875.1            546.9
# 447            17.7             15.6           877.2            556.1
# 549            96.2             37.1           872.3            555.0
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 77      0.190      0.104         29
# 359     0.147      0.086         28
# 447     0.152      0.075         28
# 549     0.224      0.097         28
#
# [4 rows x 65 columns]
# Data points considered outliers for the feature 'FIELD_FP':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 3        140       455       122        59         8        58     0.977
# 9        141       426       103        48        13        68     0.977
# 23       155       334       132        64        18        50     0.975
# 26       140       433        95        39        14        45     0.977
# 33       136       401       102        46        14        60     0.977
# 46       139       367       100        43        14        59     0.977
# 53       160       335       157        47        16        46     0.974
# 56       147       477        99        50         9        54     0.976
# 88       141       417       106        50        13        66     0.977
# 101      139       390       113        44         8        75     0.977
# 118      145       336        94        52        15        46     0.976
# 128      144       325       151        53        11        22     0.976
# 149      142       334        72        34        23        59     0.977
# 170      141       363        77        28         9        46     0.977
# 202      144       410        71        41        10        71     0.977
# 206      139       334        97        50        18        71     0.977
# 294      137       367        94        33        19        67     0.977
# 357      143       363        89        38         9        74     0.977
# 451       54       428        63        32         8        38     0.991
# 464       59       329       119        33        10        69     0.990
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 3        4315    6302     205    ...            0.287       0.756       4.18
# 9        4302    6323     221    ...            0.290       0.711       4.36
# 23       4280    6300     126    ...            0.300       0.687       4.81
# 26       4346    6042     147    ...            0.311       0.689       4.70
# 33       4315    6369     223    ...            0.262       0.742       4.74
# 46       4292    6403     168    ...            0.304       0.698       4.85
# 53       4303    6234     171    ...            0.313       0.687       4.60
# 56       4300    6136     153    ...            0.313       0.697       5.08
# 88       4386    6273     144    ...            0.296       0.700       5.54
# 101      4271    6185     164    ...            0.286       0.726       4.48
# 118      4322    6151     136    ...            0.295       0.691       5.13
# 128      4327    6362     152    ...            0.287       0.733       4.14
# 149      4241    5920     124    ...            0.296       0.688       5.11
# 170      4339    6187     172    ...            0.302       0.692       4.46
# 202      4319    6362     136    ...            0.283       0.692       4.93
# 206      4309    6209     185    ...            0.297       0.680       4.78
# 294      4331    6326     171    ...            0.304       0.682       4.56
# 357      4273    6058     125    ...            0.296       0.679       4.82
# 451      4359    6388     176    ...            0.291       0.755       3.45
# 464      4392    6334     130    ...            0.302       0.742       3.73
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 3             128.1             15.7          1020.8            433.0
# 9             156.1             25.1          1060.9            398.5
# 23            114.1             17.8           950.8            491.1
# 26            106.3             49.7           982.4            447.0
# 33            101.7             40.8           929.8            527.3
# 46             87.1              6.7           942.9            486.7
# 53            119.6             74.0           911.6            520.3
# 56            104.4            -15.1           960.1            464.0
# 88             73.5             -3.1           940.4            490.3
# 101           104.5             38.8           998.7            434.3
# 118            98.9              5.2           956.7            468.4
# 128            97.4             34.8           956.0            481.3
# 149            53.5            -27.3           975.8            459.4
# 170           145.7              1.5           974.1            453.2
# 202            46.1             25.6           865.1            544.9
# 206           102.6             -9.4           910.8            518.9
# 294           148.3             22.6          1014.6            420.7
# 357            62.8            -17.7           897.6            518.8
# 451           143.9             30.7           977.6            467.6
# 464           129.1             17.7           923.5            512.7
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 3       0.183      0.086         30
# 9       0.182      0.092         29
# 23      0.150      0.094         27
# 26      0.152      0.090         27
# 33      0.174      0.102         28
# 46      0.148      0.103         26
# 53      0.155      0.081         29
# 56      0.151      0.106         27
# 88      0.144      0.108         26
# 101     0.153      0.085         28
# 118     0.168      0.095         28
# 128     0.178      0.087         28
# 149     0.144      0.097         26
# 170     0.157      0.077         29
# 202     0.147      0.093         27
# 206     0.180      0.104         29
# 294     0.161      0.079         27
# 357     0.144      0.099         27
# 451     0.214      0.076         29
# 464     0.224      0.090         28
#
# [20 rows x 65 columns]
# Data points considered outliers for the feature 'FIELD_PO':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 299       92       352       189        20         9        42     0.985
# 411       83       315       128        41         9        61     0.987
# 437      106       371        63        36        10        34     0.983
# 455       75       338        48        22        10        84     0.988
# 484       83       314       106        39         5        74     0.986
# 535      122       434       144        43        11        67     0.981
# 570      107       332        61        39        19        43     0.982
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 299      4454    6213     131    ...            0.331       0.668       4.70
# 411      4439    6169     173    ...            0.285       0.708       4.05
# 437      4449    6094     198    ...            0.292       0.715       3.90
# 455      4485    6165     171    ...            0.290       0.769       3.83
# 484      4448    6224     156    ...            0.300       0.750       3.47
# 535      4469    5988     120    ...            0.297       0.717       4.24
# 570      4447    6271     238    ...            0.303       0.775       3.33
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 299           121.8            -32.3           930.8            492.8
# 411            77.7             51.5           937.9            513.6
# 437           149.7             47.0           982.8            455.0
# 455            95.4             57.4           984.8            458.4
# 484           111.9             35.7          1013.4            436.7
# 535            70.7             18.1           899.0            545.7
# 570           218.5             85.7           949.7            484.9
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 299     0.187      0.089         27
# 411     0.194      0.087         30
# 437     0.212      0.074         28
# 455     0.200      0.078         28
# 484     0.214      0.078         27
# 535     0.200      0.087         27
# 570     0.275      0.069         29
#
# [7 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_PA':
#     FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 30      106       423       103        62        20        65     0.983
#
#     FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 30      4294    6554     209    ...            0.289       0.733       3.85
#
#     PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 30           229.2             51.0          1051.2            414.2
#
#     PITCH_K%  PITCH_BB%  PITCH_Age
# 30     0.193      0.082         27
#
# [1 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_HR':
# Empty DataFrame
# Columns: [FIELD_E, FIELD_DP, FIELD_SB, FIELD_CS, FIELD_PB, FIELD_WP, FIELD_FP, FIELD_PO, OFF_PA, OFF_HR, OFF_R, OFF_RBI, OFF_SB, OFF_ISO, OFF_BABIP, OFF_AVG, OFF_OBP, OFF_SLG, OFF_wOBA, OFF_wRC+, OFF_H, OFF_1B, OFF_2B, OFF_3B, OFF_BB, OFF_IBB, OFF_SO, OFF_HBP, OFF_SF, OFF_GDP, OFF_CS, OFF_BB%, OFF_K%, OFF_BB/K, PITCH_ERA, PITCH_CG, PITCH_ShO, PITCH_SV, PITCH_H, PITCH_R, PITCH_ER, PITCH_HR, PITCH_BB, PITCH_IBB, PITCH_HBP, PITCH_WP, PITCH_BK, PITCH_SO, PITCH_K/9, PITCH_BB/9, PITCH_K/BB, PITCH_H/9, PITCH_HR/9, PITCH_AVG, PITCH_WHIP, PITCH_BABIP, PITCH_LOB%, PITCH_FIP, PITCH_Starting, PITCH_Relieving, PITCH_Start-IP, PITCH_Relief-IP, PITCH_K%, PITCH_BB%, PITCH_Age]
# Index: []
#
# [0 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_R':
#     FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 30      106       423       103        62        20        65     0.983
#
#     FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 30      4294    6554     209    ...            0.289       0.733       3.85
#
#     PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 30           229.2             51.0          1051.2            414.2
#
#     PITCH_K%  PITCH_BB%  PITCH_Age
# 30     0.193      0.082         27
#
# [1 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_RBI':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 30       106       423       103        62        20        65     0.983
# 150       65       377        62        32        12        35     0.989
# 270      106       384        70        26         5        56     0.982
# 389      127       292       116        32        11        56     0.979
# 479      125       414        98        37        14        61     0.979
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 30       4294    6554     209    ...            0.289       0.733       3.85
# 150      4323    6530     238    ...            0.280       0.770       3.56
# 270      4312    6528     201    ...            0.287       0.717       3.81
# 389      4235    5989     101    ...            0.311       0.674       4.45
# 479      4320    6021      95    ...            0.303       0.700       4.67
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 30            229.2             51.0          1051.2            414.2
# 150           169.1             94.1           983.6            470.1
# 270           161.9             60.5           932.2            547.1
# 389            32.4             10.2           869.1            533.7
# 479            67.5            -50.6           903.9            529.1
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 30      0.193      0.082         27
# 150     0.215      0.088         30
# 270     0.182      0.076         29
# 389     0.163      0.085         28
# 479     0.170      0.097         27
#
# [5 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_SB':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 9        141       426       103        48        13        68     0.977
# 278      101       370       107        31         8        69     0.983
# 333       98       324        90        28         7        46     0.983
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 9        4302    6323     221    ...            0.290       0.711       4.36
# 278      4305    6344     177    ...            0.293       0.718       4.30
# 333      4282    6223     199    ...            0.292       0.732       3.82
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 9             156.1             25.1          1060.9            398.5
# 278           133.7             28.4           966.1            480.1
# 333           175.9              6.5          1002.5            433.5
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 9       0.182      0.092         29
# 278     0.168      0.094         28
# 333     0.172      0.076         29
#
# [3 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_ISO':
# Empty DataFrame
# Columns: [FIELD_E, FIELD_DP, FIELD_SB, FIELD_CS, FIELD_PB, FIELD_WP, FIELD_FP, FIELD_PO, OFF_PA, OFF_HR, OFF_R, OFF_RBI, OFF_SB, OFF_ISO, OFF_BABIP, OFF_AVG, OFF_OBP, OFF_SLG, OFF_wOBA, OFF_wRC+, OFF_H, OFF_1B, OFF_2B, OFF_3B, OFF_BB, OFF_IBB, OFF_SO, OFF_HBP, OFF_SF, OFF_GDP, OFF_CS, OFF_BB%, OFF_K%, OFF_BB/K, PITCH_ERA, PITCH_CG, PITCH_ShO, PITCH_SV, PITCH_H, PITCH_R, PITCH_ER, PITCH_HR, PITCH_BB, PITCH_IBB, PITCH_HBP, PITCH_WP, PITCH_BK, PITCH_SO, PITCH_K/9, PITCH_BB/9, PITCH_K/BB, PITCH_H/9, PITCH_HR/9, PITCH_AVG, PITCH_WHIP, PITCH_BABIP, PITCH_LOB%, PITCH_FIP, PITCH_Starting, PITCH_Relieving, PITCH_Start-IP, PITCH_Relief-IP, PITCH_K%, PITCH_BB%, PITCH_Age]
# Index: []
#
# [0 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_BABIP':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 365       99       380        88        32         8        42     0.984
# 450       85       335        77        36         6        60     0.986
# 480      104       301        69        29         6        58     0.983
# 541       76       332        59        33        37        52     0.987
# 573       88       305        68        28        19        40     0.985
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 365      4295    6072     257    ...            0.289       0.753       3.93
# 450      4345    6382     178    ...            0.288       0.770       3.44
# 480      4352    6164     186    ...            0.294       0.749       3.18
# 541      4319    6236     204    ...            0.288       0.750       3.58
# 573      4334    6201     192    ...            0.303       0.757       3.78
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 365           129.6             17.7          1032.3            417.5
# 450           119.6             44.6           987.8            458.1
# 480           159.3             49.2          1000.0            465.3
# 541           168.1             49.1           957.9            495.7
# 573           161.4             68.5           949.7            526.1
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 365     0.194      0.068         30
# 450     0.206      0.068         28
# 480     0.214      0.059         28
# 541     0.245      0.078         28
# 573     0.254      0.075         29
#
# [5 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_AVG':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 509      106       373       109        32        14        57     0.983
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 509      4316    5905     109    ...            0.307       0.692       4.43
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 509            52.3             -2.1           902.3            521.7
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 509     0.172      0.085         28
#
# [1 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_OBP':
#     FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 30      106       423       103        62        20        65     0.983
#
#     FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 30      4294    6554     209    ...            0.289       0.733       3.85
#
#     PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 30           229.2             51.0          1051.2            414.2
#
#     PITCH_K%  PITCH_BB%  PITCH_Age
# 30     0.193      0.082         27
#
# [1 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_SLG':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 150       65       377        62        32        12        35     0.989
# 389      127       292       116        32        11        56     0.979
# 479      125       414        98        37        14        61     0.979
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 150      4323    6530     238    ...            0.280       0.770       3.56
# 389      4235    5989     101    ...            0.311       0.674       4.45
# 479      4320    6021      95    ...            0.303       0.700       4.67
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 150           169.1             94.1           983.6            470.1
# 389            32.4             10.2           869.1            533.7
# 479            67.5            -50.6           903.9            529.1
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 150     0.215      0.088         30
# 389     0.163      0.085         28
# 479     0.170      0.097         27
#
# [3 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_wOBA':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 30       106       423       103        62        20        65     0.983
# 479      125       414        98        37        14        61     0.979
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 30       4294    6554     209    ...            0.289       0.733       3.85
# 479      4320    6021      95    ...            0.303       0.700       4.67
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 30            229.2             51.0          1051.2            414.2
# 479            67.5            -50.6           903.9            529.1
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 30      0.193      0.082         27
# 479     0.170      0.097         27
#
# [2 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_wRC+':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 570      107       332        61        39        19        43     0.982
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 570      4447    6271     238    ...            0.303       0.775       3.33
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 570           218.5             85.7           949.7            484.9
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 570     0.275      0.069         29
#
# [1 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_H':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 509      106       373       109        32        14        57     0.983
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 509      4316    5905     109    ...            0.307       0.692       4.43
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 509            52.3             -2.1           902.3            521.7
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 509     0.172      0.085         28
#
# [1 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_1B':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 76       100       366        94        54         6        45     0.983
# 249       84       417        88        41        10        43     0.986
# 282      102       416       134        24         6        42     0.984
# 365       99       380        88        32         8        42     0.984
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 76       4364    6394     150    ...            0.292       0.705       4.81
# 249      4355    6228     143    ...            0.292       0.717       4.51
# 282      4346    6209     153    ...            0.296       0.694       4.23
# 365      4295    6072     257    ...            0.289       0.753       3.93
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 76            138.0            -23.7          1002.0            429.9
# 249           107.0             46.7           896.3            524.8
# 282           135.0             33.4           950.2            490.1
# 365           129.6             17.7          1032.3            417.5
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 76      0.178      0.101         28
# 249     0.175      0.082         27
# 282     0.166      0.085         27
# 365     0.194      0.068         30
#
# [4 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_2B':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 27       142       422        92        44         6        42     0.978
# 150       65       377        62        32        12        35     0.989
# 178      114       343       100        37        14        57     0.981
# 180      119       344        67        32         8        55     0.980
# 300       90       389        76        31        10        52     0.985
# 450       85       335        77        36         6        60     0.986
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 27       4407    6077     159    ...            0.307       0.679       4.83
# 150      4323    6530     238    ...            0.280       0.770       3.56
# 178      4356    6071     153    ...            0.296       0.665       5.01
# 180      4251    6515     222    ...            0.276       0.744       4.17
# 300      4373    6478     194    ...            0.284       0.748       3.81
# 450      4345    6382     178    ...            0.288       0.770       3.44
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 27             90.1             27.2           959.6            471.6
# 150           169.1             94.1           983.6            470.1
# 178            41.8            -12.5           883.1            548.8
# 180           110.5             56.4           995.4            455.0
# 300           185.4             39.0          1020.5            422.9
# 450           119.6             44.6           987.8            458.1
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 27      0.157      0.089         27
# 150     0.215      0.088         30
# 178     0.120      0.087         26
# 180     0.171      0.072         29
# 300     0.195      0.077         29
# 450     0.206      0.068         28
#
# [6 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_3B':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 90       103       379       109        59        16        46     0.983
# 113      108       374       128        33        12        55     0.982
# 248      102       373        80        50        15        59     0.983
# 432       72       391       128        39        20        61     0.988
# 551       86       283        86        31        14        52     0.985
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 90       4313    6394     213    ...            0.260       0.748       4.12
# 113      4294    6145     139    ...            0.297       0.692       4.70
# 248      4257    6394     153    ...            0.299       0.720       4.59
# 432      4370    6200     103    ...            0.285       0.738       4.20
# 551      4285    6260     190    ...            0.304       0.718       3.88
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 90            132.1             55.9           992.7            468.1
# 113            58.9             41.7           872.9            564.4
# 248           112.6             10.9           945.0            481.8
# 432            95.4             59.4           934.4            540.9
# 551           125.9             39.3           931.3            509.8
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 90      0.172      0.076         29
# 113     0.149      0.081         27
# 248     0.173      0.099         25
# 432     0.188      0.077         28
# 551     0.209      0.077         27
#
# [5 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_BB':
#     FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 30      106       423       103        62        20        65     0.983
# 35      106       424        81        44        12        43     0.982
# 46      139       367       100        43        14        59     0.977
# 64       72       403       109        42        10        50     0.988
# 68      109       349        91        37        13        49     0.981
#
#     FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 30      4294    6554     209    ...            0.289       0.733       3.85
# 35      4263    6442     235    ...            0.288       0.720       4.35
# 46      4292    6403     168    ...            0.304       0.698       4.85
# 64      4327    6432     239    ...            0.288       0.712       4.29
# 68      4273    6444     198    ...            0.282       0.711       4.84
#
#     PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 30           229.2             51.0          1051.2            414.2
# 35           169.2             57.2          1000.1            434.9
# 46            87.1              6.7           942.9            486.7
# 64           143.9             61.6           884.0            561.2
# 68            79.7             20.9           975.2            476.9
#
#     PITCH_K%  PITCH_BB%  PITCH_Age
# 30     0.193      0.082         27
# 35     0.178      0.093         29
# 46     0.148      0.103         26
# 64     0.180      0.080         29
# 68     0.167      0.101         28
#
# [5 rows x 65 columns]
# Data points considered outliers for the feature 'OFF_IBB':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 95       131       447       104        50        30        40     0.979
# 98       109       348       146        45        21        54     0.982
# 124       87       356        78        51         7        52     0.986
# 132      120       392        67        42        28        52     0.981
# 135      103       366       109        49        12        64     0.983
# 164       94       403        96        45        11        51     0.985
# 187      117       383        71        39        16        34     0.981
# 215      106       389       103        33         6        26     0.983
# 267      104       410       102        52        16        61     0.983
# 272      107       333        98        30        10        48     0.983
# 299       92       352       189        20         9        42     0.985
# 341       98       379        82        21         6        61     0.984
# 348       96       390        97        46        12        40     0.985
# 375       92       416        69        35        10        69     0.985
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 95       4288    6408     235    ...            0.294       0.727       3.91
# 98       4354    6349     208    ...            0.287       0.729       4.31
# 124      4357    6304     198    ...            0.270       0.755       4.12
# 132      4360    6246     175    ...            0.284       0.730       4.11
# 135      4293    6250     162    ...            0.290       0.728       4.49
# 164      4300    6204     180    ...            0.283       0.726       4.57
# 187      4318    6466     183    ...            0.288       0.729       4.17
# 215      4358    6345     167    ...            0.271       0.734       4.08
# 267      4305    6136     163    ...            0.292       0.690       4.97
# 272      4369    6537     213    ...            0.282       0.718       4.28
# 299      4454    6213     131    ...            0.331       0.668       4.70
# 341      4305    6385     145    ...            0.302       0.703       4.10
# 348      4388    6168     160    ...            0.298       0.698       4.20
# 375      4322    6241     150    ...            0.305       0.710       3.89
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 95            169.6             50.9           970.7            460.7
# 98            103.7             33.4           958.8            481.4
# 124           121.5             37.3           984.6            468.4
# 132           123.4             58.8           996.0            443.5
# 135            49.4             20.9           894.1            513.2
# 164            61.0             52.8           925.9            500.3
# 187           146.9             13.2           972.0            460.7
# 215           137.4             41.6           999.8            444.7
# 267            49.4             -2.4           875.6            551.4
# 272           120.0             52.9           996.1            447.2
# 299           121.8            -32.3           930.8            492.8
# 341            86.5             77.8           884.5            555.6
# 348           118.1             30.3           965.8            477.9
# 375           136.9             11.0           974.7            459.5
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 95      0.218      0.089         28
# 98      0.175      0.085         29
# 124     0.184      0.090         32
# ...
# 596      4395    6073     186    ...            0.302       0.722       4.96
# 598      4338    5954     189    ...            0.296       0.711       5.08
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 391           144.6             40.5           995.1            467.3
# 566            21.5            -41.1           856.9            577.4
# 594            16.8             22.8           869.6            542.5
# 596            53.7             22.1           843.2            588.7
# 598            23.7              7.5           817.9            605.1
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 391     0.215      0.091         29
# 566     0.196      0.100         27
# 594     0.192      0.102         28
# 596     0.196      0.092         27
# 598     0.207      0.100         26
#
# [5 rows x 65 columns]
# Data points considered outliers for the feature 'PITCH_AVG':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 540      101       277       133        38        12        80     0.984
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 540      4379    6320     208    ...            0.255       0.775       3.77
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 540           162.6             30.3           986.9            467.4
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 540     0.243      0.083         29
#
# [1 rows x 65 columns]
# Data points considered outliers for the feature 'PITCH_WHIP':
#     FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 59      105       418       129        53         8        62     0.983
#
#     FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 59      4368    6124     105    ...            0.325       0.679       5.52
#
#     PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 59            79.7              7.3           933.0            491.1
#
#     PITCH_K%  PITCH_BB%  PITCH_Age
# 59     0.157      0.112         28
#
# [1 rows x 65 columns]
# Data points considered outliers for the feature 'PITCH_BABIP':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 33       136       401       102        46        14        60     0.977
# 59       105       418       129        53         8        62     0.983
# 90       103       379       109        59        16        46     0.983
# 299       92       352       189        20         9        42     0.985
# 449       96       390       140        37        13        67     0.984
# 540      101       277       133        38        12        80     0.984
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 33       4315    6369     223    ...            0.262       0.742       4.74
# 59       4368    6124     105    ...            0.325       0.679       5.52
# 90       4313    6394     213    ...            0.260       0.748       4.12
# 299      4454    6213     131    ...            0.331       0.668       4.70
# 449      4326    6057     149    ...            0.325       0.689       4.59
# 540      4379    6320     208    ...            0.255       0.775       3.77
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 33            101.7             40.8           929.8            527.3
# 59             79.7              7.3           933.0            491.1
# 90            132.1             55.9           992.7            468.1
# 299           121.8            -32.3           930.8            492.8
# 449            23.0             40.9           760.8            652.1
# 540           162.6             30.3           986.9            467.4
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 33      0.174      0.102         28
# 59      0.157      0.112         28
# 90      0.172      0.076         29
# 299     0.187      0.089         27
# 449     0.179      0.089         28
# 540     0.243      0.083         29
#
# [6 rows x 65 columns]
# Data points considered outliers for the feature 'PITCH_LOB%':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 510       88       323        75        35         5        62     0.986
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 510      4356    6231     232    ...            0.297       0.794       3.48
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 510           151.5             42.2           977.1            480.8
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 510     0.217      0.078         28
#
# [1 rows x 65 columns]
# Data points considered outliers for the feature 'PITCH_FIP':
#     FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 59      105       418       129        53         8        62     0.983
# 88      141       417       106        50        13        66     0.977
#
#     FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 59      4368    6124     105    ...            0.325       0.679       5.52
# 88      4386    6273     144    ...            0.296       0.700       5.54
#
#     PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 59            79.7              7.3           933.0            491.1
# 88            73.5             -3.1           940.4            490.3
#
#     PITCH_K%  PITCH_BB%  PITCH_Age
# 59     0.157      0.112         28
# 88     0.144      0.108         26
#
# [2 rows x 65 columns]
# Data points considered outliers for the feature 'PITCH_Starting':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 0        106       392       156        65        29        70     0.983
# 30       106       423       103        62        20        65     0.983
# 32       127       346       159        58        31        28     0.979
# 129      125       407        92        53        13        62     0.979
# 158       87       268        70        27        10        62     0.985
# 390       90       313        61        43         9        39     0.985
# 570      107       332        61        39        19        43     0.982
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 0        4329    6444     207    ...            0.285       0.744       3.53
# 30       4294    6554     209    ...            0.289       0.733       3.85
# 32       4310    6416     193    ...            0.312       0.728       3.69
# 129      4321    6196     167    ...            0.289       0.727       3.67
# 158      4385    6324     155    ...            0.302       0.704       3.66
# 390      4330    6414     203    ...            0.286       0.775       3.24
# 570      4447    6271     238    ...            0.303       0.775       3.33
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 0             230.9             24.8          1072.8            361.2
# 30            229.2             51.0          1051.2            414.2
# 32            219.1             51.6          1054.5            400.2
# 129           216.7             24.7          1057.0            384.3
# 158           231.5             47.3          1063.2            390.4
# 390           224.6             18.9          1063.5            409.3
# 570           218.5             85.7           949.7            484.9
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 0       0.207      0.078         29
# 30      0.193      0.082         27
# 32      0.194      0.077         27
# 129     0.215      0.069         32
# 158     0.180      0.060         31
# 390     0.214      0.067         29
# 570     0.275      0.069         29
#
# [7 rows x 65 columns]
# Data points considered outliers for the feature 'PITCH_Relieving':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 150       65       377        62        32        12        35     0.989
# 387      111       327       169        42        14        58     0.982
# 479      125       414        98        37        14        61     0.979
# 566      126       437        78        20         9        83     0.979
# 574       95       338       121        35        13        73     0.984
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 150      4323    6530     238    ...            0.280       0.770       3.56
# 387      4370    5974     126    ...            0.296       0.701       4.76
# 479      4320    6021      95    ...            0.303       0.700       4.67
# 566      4329    6192     122    ...            0.290       0.728       5.24
# 574      4342    6283     223    ...            0.280       0.745       3.88
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 150           169.1             94.1           983.6            470.1
# 387            62.8            -32.7           991.6            435.5
# 479            67.5            -50.6           903.9            529.1
# 566            21.5            -41.1           856.9            577.4
# 574           148.0             91.0           908.0            534.6
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 150     0.215      0.088         30
# 387     0.171      0.088         28
# 479     0.170      0.097         27
# 566     0.196      0.100         27
# 574     0.257      0.083         27
#
# [5 rows x 65 columns]
# Data points considered outliers for the feature 'PITCH_Start-IP':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 449       96       390       140        37        13        67     0.984
# 598       99       376       102        14        16        86     0.983
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 449      4326    6057     149    ...            0.325       0.689       4.59
# 598      4338    5954     189    ...            0.296       0.711       5.08
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 449            23.0             40.9           760.8            652.1
# 598            23.7              7.5           817.9            605.1
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 449     0.179      0.089         28
# 598     0.207      0.100         26
#
# [2 rows x 65 columns]
# Data points considered outliers for the feature 'PITCH_Relief-IP':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 0        106       392       156        65        29        70     0.983
# 449       96       390       140        37        13        67     0.984
# 595      113       441        76        34         8        73     0.981
# 598       99       376       102        14        16        86     0.983
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 0        4329    6444     207    ...            0.285       0.744       3.53
# 449      4326    6057     149    ...            0.325       0.689       4.59
# 595      4292    6133     174    ...            0.298       0.707       4.69
# 598      4338    5954     189    ...            0.296       0.711       5.08
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 0             230.9             24.8          1072.8            361.2
# 449            23.0             40.9           760.8            652.1
# 595            38.2             19.4           827.4            607.8
# 598            23.7              7.5           817.9            605.1
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 0       0.207      0.078         29
# 449     0.179      0.089         28
# 595     0.190      0.099         28
# 598     0.207      0.100         26
#
# [4 rows x 65 columns]
# Data points considered outliers for the feature 'PITCH_K%':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 541       76       332        59        33        37        52     0.987
# 544       72       348        71        35         6        40     0.988
# 570      107       332        61        39        19        43     0.982
# 571       80       323        71        43        10        57     0.986
# 573       88       305        68        28        19        40     0.985
# 574       95       338       121        35        13        73     0.984
# 580       78       359        75        29        16        52     0.987
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 541      4319    6236     204    ...            0.288       0.750       3.58
# 544      4381    6223     225    ...            0.288       0.738       3.61
# 570      4447    6271     238    ...            0.303       0.775       3.33
# 571      4322    6234     212    ...            0.281       0.778       3.67
# 573      4334    6201     192    ...            0.303       0.757       3.78
# 574      4342    6283     223    ...            0.280       0.745       3.88
# 580      4308    6213     219    ...            0.300       0.737       3.91
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 541           168.1             49.1           957.9            495.7
# 544           144.8             61.2           859.3            584.6
# 570           218.5             85.7           949.7            484.9
# 571           160.9             74.1           882.2            555.0
# 573           161.4             68.5           949.7            526.1
# 574           148.0             91.0           908.0            534.6
# 580           146.7             55.7           896.4            542.6
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 541     0.245      0.078         28
# 544     0.251      0.077         28
# 570     0.275      0.069         29
# 571     0.261      0.075         29
# 573     0.254      0.075         29
# 574     0.257      0.083         27
# 580     0.261      0.085         28
#
# [7 rows x 65 columns]
# Data points considered outliers for the feature 'PITCH_BB%':
#      FIELD_E  FIELD_DP  FIELD_SB  FIELD_CS  FIELD_PB  FIELD_WP  FIELD_FP  \
# 59       105       418       129        53         8        62     0.983
# 72       135       436        65        37         8        40     0.978
# 216      110       418        60        49         4        53     0.982
#
#      FIELD_PO  OFF_PA  OFF_HR    ...      PITCH_BABIP  PITCH_LOB%  PITCH_FIP  \
# 59       4368    6124     105    ...            0.325       0.679       5.52
# 72       4287    6373     200    ...            0.291       0.716       4.98
# 216      4307    6186     184    ...            0.283       0.736       4.00
#
#      PITCH_Starting  PITCH_Relieving  PITCH_Start-IP  PITCH_Relief-IP  \
# 59             79.7              7.3           933.0            491.1
# 72             77.5             28.0           961.3            498.5
# 216           144.8             38.9          1022.4            436.8
#
#      PITCH_K%  PITCH_BB%  PITCH_Age
# 59      0.157      0.112         28
# 72      0.149      0.112         27
# 216     0.159      0.057         27
#
# [3 rows x 65 columns]
# Data points considered outliers for the feature 'PITCH_Age':
# Empty DataFrame
# Columns: [FIELD_E, FIELD_DP, FIELD_SB, FIELD_CS, FIELD_PB, FIELD_WP, FIELD_FP, FIELD_PO, OFF_PA, OFF_HR, OFF_R, OFF_RBI, OFF_SB, OFF_ISO, OFF_BABIP, OFF_AVG, OFF_OBP, OFF_SLG, OFF_wOBA, OFF_wRC+, OFF_H, OFF_1B, OFF_2B, OFF_3B, OFF_BB, OFF_IBB, OFF_SO, OFF_HBP, OFF_SF, OFF_GDP, OFF_CS, OFF_BB%, OFF_K%, OFF_BB/K, PITCH_ERA, PITCH_CG, PITCH_ShO, PITCH_SV, PITCH_H, PITCH_R, PITCH_ER, PITCH_HR, PITCH_BB, PITCH_IBB, PITCH_HBP, PITCH_WP, PITCH_BK, PITCH_SO, PITCH_K/9, PITCH_BB/9, PITCH_K/BB, PITCH_H/9, PITCH_HR/9, PITCH_AVG, PITCH_WHIP, PITCH_BABIP, PITCH_LOB%, PITCH_FIP, PITCH_Starting, PITCH_Relieving, PITCH_Start-IP, PITCH_Relief-IP, PITCH_K%, PITCH_BB%, PITCH_Age]
# Index: []
#
# [0 rows x 65 columns]

# %% [markdown]
# ####  <a id='3.1'><font color=black><u>3.1 Remove Outliers </u></font></a>
#
# From the dictionary, we can see that six observations at indexes 59, 30, 570, 573, and 598 have a high number of outlier features (more than 4).  These observations are removed from both the features and Wins datasets.  The number of observations for both datasets is now 594.

# %%
pp.pprint(cnt)
# Out:
# Counter({59: 11,
#          30: 8,
#          570: 7,
#          0: 6,
#          573: 5,
#          598: 5,
#          92: 4,
#          299: 4,
#          32: 4,
#          46: 4,
#          150: 4,
#          479: 4,
#          540: 4,
#          72: 4,
#          449: 4,
#          571: 4,
#          574: 4,
#          23: 3,
#          48: 3,
#          223: 3,
#          5: 3,
#          24: 3,
#          49: 3,
#          149: 3,
#          541: 3,
#          9: 3,
#          365: 3,
#          267: 3,
#          477: 3,
#          390: 3,
#          566: 3,
#          580: 3,
#          53: 2,
#          451: 2,
#          18: 2,
#          31: 2,
#          41: 2,
#          1: 2,
#          387: 2,
#          44: 2,
#          2: 2,
#          95: 2,
#          132: 2,
#          447: 2,
#          513: 2,
#          33: 2,
#          88: 2,
#          128: 2,
#          170: 2,
#          202: 2,
#          206: 2,
#          411: 2,
#          389: 2,
#          450: 2,
#          480: 2,
#          509: 2,
#          76: 2,
#          300: 2,
#          90: 2,
#          35: 2,
#          64: 2,
#          68: 2,
#          135: 2,
#          187: 2,
#          555: 2,
#          585: 2,
#          591: 2,
#          129: 2,
#          210: 2,
#          510: 2,
#          391: 2,
#          594: 2,
#          596: 2,
#          22: 1,
#          36: 1,
#          63: 1,
#          82: 1,
#          96: 1,
#          443: 1,
#          489: 1,
#          52: 1,
#          324: 1,
#          14: 1,
#          57: 1,
#          87: 1,
#          102: 1,
#          152: 1,
#          62: 1,
#          127: 1,
#          265: 1,
#          395: 1,
#          419: 1,
#          446: 1,
#          474: 1,
#          526: 1,
#          538: 1,
#          553: 1,
#          77: 1,
#          359: 1,
#          549: 1,
#          3: 1,
#          26: 1,
#          56: 1,
#          101: 1,
#          118: 1,
#          294: 1,
#          357: 1,
#          464: 1,
#          437: 1,
#          455: 1,
#          484: 1,
#          535: 1,
#          270: 1,
#          278: 1,
#          333: 1,
#          249: 1,
#          282: 1,
#          27: 1,
#          178: 1,
#          180: 1,
#          113: 1,
#          248: 1,
#          432: 1,
#          551: 1,
#          98: 1,
#          124: 1,
#          164: 1,
#          215: 1,
#          272: 1,
#          341: 1,
#          348: 1,
#          375: 1,
#          373: 1,
#          204: 1,
#          244: 1,
#          308: 1,
#          542: 1,
#          67: 1,
#          184: 1,
#          316: 1,
#          119: 1,
#          136: 1,
#          165: 1,
#          368: 1,
#          568: 1,
#          4: 1,
#          19: 1,
#          20: 1,
#          66: 1,
#          83: 1,
#          86: 1,
#          116: 1,
#          151: 1,
#          157: 1,
#          397: 1,
#          160: 1,
#          402: 1,
#          307: 1,
#          28: 1,
#          110: 1,
#          130: 1,
#          131: 1,
#          142: 1,
#          194: 1,
#          209: 1,
#          218: 1,
#          262: 1,
#          275: 1,
#          320: 1,
#          99: 1,
#          108: 1,
#          173: 1,
#          190: 1,
#          233: 1,
#          487: 1,
#          65: 1,
#          355: 1,
#          550: 1,
#          6: 1,
#          10: 1,
#          16: 1,
#          431: 1,
#          497: 1,
#          512: 1,
#          514: 1,
#          516: 1,
#          158: 1,
#          595: 1,
#          544: 1,
#          216: 1})

# %%
features = features.drop([59,30,570,0,573,598])
Wins = Wins.drop([59,30,570,0,573,598])

# %%
print(Wins.shape)
print(features.shape)
# Out:
# (594,)
# (594, 65)

# %% [markdown]
# #### <a id='4.0'><font color=black><u>4.0 Check for Skewness </u></font></a>
#
# Skewness is a measure of symmetry, or lack thereof, in a dataset while Kurtosis is a measure of how large the tails are compared to a normal distribution.  If both skew and kurtosis are 0, then the data is normally distributed.  In the code below, I culled out those features with a skew and kurtosis greater than .5

# %%
from scipy.stats import kurtosis
from scipy.stats import skew

skewed_features = {}
 
for col in features.columns:
    arry = np.array(features[col])
    skew_value = skew(arry)
    if skew_value> 1 or skew_value < -1:
        skewed_features[col] = [skew_value]
    
skewed_features
# Out:
# {'FIELD_PB': [1.4430653832375777],
#  'OFF_IBB': [1.433840489666504],
#  'PITCH_CG': [1.1213488048517393]}

# %%
plt.hist(x=features['OFF_IBB'], bins=50)
plt.xlabel('Number of Intentional Walks for a Team')
plt.title("Pre Transformed Feature Intentional Walks")
# Out:
# Text(0.5,1,'Pre Transformed Feature Intentional Walks')

# %%
plt.hist(x=features['FIELD_PB'], bins=50)
plt.xlabel('Number of Passed Balls(Errors) for a Team')
plt.title("Pre Transformed Feature Passed Balls")
# Out:
# Text(0.5,1,'Pre Transformed Feature Passed Balls')

# %%
plt.hist(x=features['FIELD_PB'], bins=50)
plt.xlabel('Number of Passed Balls(Errors) for a Team')
plt.title("Pre Transformed Feature Complete Games")
# Out:
# Text(0.5,1,'Pre Transformed Feature Complete Games')

# %% [markdown]
# #### <a id='4.1'><font color=black><u>4.1 Check for Skewness </u></font></a>
#
# In this section, I transformed the skewed features of the dataset identified above by taking the log of the feature + 1.

# %%
# Log-transform the skewed features
skewed = [keys for keys in skewed_features.keys()]
features[skewed] = features[skewed].apply(lambda x: np.log(x+1))

# %%
transformed_skewed_features = {}

for col in features[skewed]:
    arry = np.array(features[col])
    skew_value = skew(arry)
    transformed_skewed_features[col] = [skew_value]
        
transformed_skewed_features
# Out:
# {'FIELD_PB': [-0.10245758057950705],
#  'OFF_IBB': [-0.13524340778622712],
#  'PITCH_CG': [-0.48821069210848994]}

# %%
plt.hist(x=features['OFF_IBB'], bins=50)
plt.xlabel('Number of Intentional Walks for a Team')
plt.title("Transformed Feature Intentional Walks for a Team")
# Out:
# Text(0.5,1,'Transformed Feature Intentional Walks for a Team')

# %%
plt.hist(x=features['FIELD_PB'], bins=50)
plt.xlabel('Number of Passed Balls(Errors) for a Team')
plt.title("Transformed Feature Intentional Walks for a Team")
# Out:
# Text(0.5,1,'Transformed Feature Intentional Walks for a Team')

# %%
plt.hist(x=features['PITCH_CG'], bins=50)
plt.xlabel('Number of Complete Games Pitched by a Starter for a Team')
plt.title("Transformed Feature Complete Games Pitched by a Starter for a Team")
# Out:
# Text(0.5,1,'Transformed Feature Complete Games Pitched by a Starter for a Team')

# %% [markdown]
# #### <a id='5.0'><font color=black><u>5.0 Pre Process Dataset </u></font></a>
#
# In this section, I applied the MinMaxScaler to the log transformed features in order to better normalize the data.

# %%
scaler =  MinMaxScaler()

numerical = features.columns.values.tolist()

features[numerical ] = scaler.fit_transform(features[numerical])

# %%
features.columns.values
# Out:
# array(['FIELD_E', 'FIELD_DP', 'FIELD_SB', 'FIELD_CS', 'FIELD_PB',
#        'FIELD_WP', 'FIELD_FP', 'FIELD_PO', 'OFF_PA', 'OFF_HR', 'OFF_R',
#        'OFF_RBI', 'OFF_SB', 'OFF_ISO', 'OFF_BABIP', 'OFF_AVG', 'OFF_OBP',
#        'OFF_SLG', 'OFF_wOBA', 'OFF_wRC+', 'OFF_H', 'OFF_1B', 'OFF_2B',
#        'OFF_3B', 'OFF_BB', 'OFF_IBB', 'OFF_SO', 'OFF_HBP', 'OFF_SF',
#        'OFF_GDP', 'OFF_CS', 'OFF_BB%', 'OFF_K%', 'OFF_BB/K', 'PITCH_ERA',
#        'PITCH_CG', 'PITCH_ShO', 'PITCH_SV', 'PITCH_H', 'PITCH_R',
#        'PITCH_ER', 'PITCH_HR', 'PITCH_BB', 'PITCH_IBB', 'PITCH_HBP',
#        'PITCH_WP', 'PITCH_BK', 'PITCH_SO', 'PITCH_K/9', 'PITCH_BB/9',
#        'PITCH_K/BB', 'PITCH_H/9', 'PITCH_HR/9', 'PITCH_AVG', 'PITCH_WHIP',
#        'PITCH_BABIP', 'PITCH_LOB%', 'PITCH_FIP', 'PITCH_Starting',
#        'PITCH_Relieving', 'PITCH_Start-IP', 'PITCH_Relief-IP', 'PITCH_K%',
#        'PITCH_BB%', 'PITCH_Age'], dtype=object)

# %%
from sklearn.feature_selection import SelectKBest, f_regression


kbest = SelectKBest(f_regression, k='all')
kbest.fit_transform(features, Wins)

scores = kbest.scores_
features_scores = dict(zip(features,scores))
feats = list()
for k,v in features_scores.items():
    if v > 50:
        feats.append(k)
features = features[feats]
features_scores = sorted(features_scores.items(), key=lambda kv: kv[1])
print("These are the top 40 features, and their scores, that will be fed into the model:")
pp.pprint(features_scores)
# Out:
# These are the top 40 features, and their scores, that will be fed into the model:
# [('FIELD_CS', 0.10578656758130617),
#  ('OFF_SO', 0.4003560774847838),
#  ('OFF_3B', 0.5363084585594609),
#  ('OFF_IBB', 0.7571926132987817),
#  ('OFF_SB', 2.6334717995287535),
#  ('FIELD_PB', 3.325352938148562),
#  ('FIELD_DP', 3.7064575153649972),
#  ('OFF_K%', 4.07378707560862),
#  ('FIELD_PO', 5.045198578127768),
#  ('FIELD_WP', 5.967295422849889),
#  ('FIELD_SB', 8.194268599199686),
#  ('OFF_GDP', 9.798202918045266),
#  ('OFF_HBP', 10.618172088276818),
#  ('OFF_CS', 11.344658620231398),
#  ('PITCH_HBP', 11.842162680091043),
#  ('PITCH_CG', 13.446022712515678),
#  ('OFF_1B', 18.667720492638843),
#  ('PITCH_BK', 23.3488836873998),
#  ('PITCH_IBB', 23.64907514134771),
#  ('OFF_SF', 31.882488061452477),
#  ('PITCH_WP', 32.26984728903359),
#  ('OFF_BB/K', 34.94103127988787),
#  ('FIELD_FP', 43.80174295937833),
#  ('FIELD_E', 47.451691799896004),
#  ('OFF_BB%', 48.38786275773814),
#  ('PITCH_ShO', 50.52080752969474),
#  ('OFF_BB', 60.371597308890635),
#  ('PITCH_K/9', 61.16280595503294),
#  ('PITCH_SO', 74.05450372070902),
#  ('PITCH_Relief-IP', 74.33659861313636),
#  ('PITCH_HR', 91.78267384853879),
#  ('OFF_BABIP', 92.85451364527063),
#  ('PITCH_Age', 95.27867313571944),
#  ('PITCH_K%', 95.72054076268962),
#  ('PITCH_HR/9', 103.47385472735594),
#  ('OFF_2B', 104.56463989398351),
#  ('PITCH_BB%', 106.04581798067996),
#  ('OFF_PA', 120.48280732288728),
#  ('PITCH_BB', 127.67580706224683),
#  ('PITCH_BABIP', 131.2493204100552),
#  ('OFF_HR', 142.58907908736148),
#  ('PITCH_BB/9', 147.17434772108342),
#  ('OFF_H', 149.79136834887095),
#  ('OFF_AVG', 154.55571656983886),
#  ('PITCH_Start-IP', 155.450735050935),
#  ('PITCH_K/BB', 161.56728227366614),
#  ('OFF_ISO', 177.52793323945951),
#  ('OFF_OBP', 188.06293319559774),
#  ('PITCH_Relieving', 200.5342866078587),
#  ('PITCH_FIP', 207.18827291480525),
#  ('PITCH_H', 223.13175155169336),
#  ('OFF_R', 230.17138601749807),
#  ('OFF_RBI', 234.29257729106249),
#  ('PITCH_AVG', 264.1603292333018),
#  ('OFF_SLG', 266.99408411046574),
#  ('PITCH_H/9', 269.58925882027506),
#  ('OFF_wOBA', 287.5881306132427),
#  ('OFF_wRC+', 289.61079313366207),
#  ('PITCH_LOB%', 298.08188539925743),
#  ('PITCH_ER', 346.2428106724414),
#  ('PITCH_WHIP', 351.5725737123059),
#  ('PITCH_Starting', 356.4349253678637),
#  ('PITCH_ERA', 369.0908584698321),
#  ('PITCH_R', 373.2739748663168),
#  ('PITCH_SV', 440.1601064959799)]

# %% [markdown]
# #### <a id='5.2'><font color=black><u>5.2 Split the Dataset </u></font></a>

# %%
#Shuffle and split the data into training and testing subsets
X_train, X_test, y_train, y_test = train_test_split(features, Wins, test_size=.2, random_state=9)
print ("Training and testing split was successful.")
# Out:
# Training and testing split was successful.

# %%
features.columns.values
# Out:
# array(['OFF_PA', 'OFF_HR', 'OFF_R', 'OFF_RBI', 'OFF_ISO', 'OFF_BABIP',
#        'OFF_AVG', 'OFF_OBP', 'OFF_SLG', 'OFF_wOBA', 'OFF_wRC+', 'OFF_H',
#        'OFF_2B', 'OFF_BB', 'PITCH_ERA', 'PITCH_ShO', 'PITCH_SV',
#        'PITCH_H', 'PITCH_R', 'PITCH_ER', 'PITCH_HR', 'PITCH_BB',
#        'PITCH_SO', 'PITCH_K/9', 'PITCH_BB/9', 'PITCH_K/BB', 'PITCH_H/9',
#        'PITCH_HR/9', 'PITCH_AVG', 'PITCH_WHIP', 'PITCH_BABIP',
#        'PITCH_LOB%', 'PITCH_FIP', 'PITCH_Starting', 'PITCH_Relieving',
#        'PITCH_Start-IP', 'PITCH_Relief-IP', 'PITCH_K%', 'PITCH_BB%',
#        'PITCH_Age'], dtype=object)

# %% [markdown]
#  #### <a id='6.0'><font color=black><u>6.0 Model One: LASSO Regression </u></font></a>
#
# Least Absolute Selection and Shrinkage Operator or "LASSO" regression model was the first choice for this project given the high number of features in the dataset and the low number of observations. LASSO is a regression analysis method that performs both variable selection and regularization in order to enhance the prediction accuracy and interpretability of the statistical model it produces.LASSO imposes a constraint on the sum of the absolute values of the model parameters, where the sum has a specified constant as an upper bound. This constraint causes regression coefficients for some variables to shrink towards zero,  effectively choosing a simpler model that does not include those coefficients. https://en.wikipedia.org/wiki/Lasso_(statistics).
#
# In the Lasso regression model imported from sklearn, uses Regularization penalizes model complexity. The lambda parameter penalizes the coefficients so that the model does not over fit. Ridge Regression uses L1 Regularizaton. Ridge regression improves prediction error by shrinking large regression coefficients in order to reduce overfitting, but it does not perform covariate selection and therefore does not help to make the model more interpretable. https://en.wikipedia.org/wiki/Lasso_(statistics)
#
# Lasso uses L2 Regularization which forces the sum of the absolute value of the regression coefficients to be less than a fixed value, and in turn forces certain coefficients to be set to zero, effectively choosing a simpler model that does not include those coefficients. https://en.wikipedia.org/wiki/Lasso_(statistics)
#
# In sum, due to the high number of features, the model will reduce the coefficients of most of them to zero in order to create a simpler, more accurate prediction model.

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

lasso = Lasso(random_state=5)
alphas = 10**np.linspace(10, -2, 100)*0.5

tuned_parameters = [{'alpha': alphas}]
n_folds = 25

clf = GridSearchCV(lasso, tuned_parameters, cv=n_folds)
clf.fit(X_train, y_train)

scores = clf.cv_results_['mean_test_score']
scores_std = clf.cv_results_['std_test_score']

# %% [markdown]
# In the graph below, you can visually see how the Lasso model sets the weights of several of the features to zero thereby removing it from the prediction model.

# %%
# pp.pprint(clf.cv_results_['params'])
plt.figure(figsize=(10,10))
top_coef = pd.Series(clf.best_estimator_.coef_, X_train.columns).sort_values()
top_coef.plot(kind='bar', title='Weights of Feature Coefficients')

# %% [markdown]
# The mean squared error measures the average squared difference between the prediction values and the actual values. The MSE is lower on the training set than it is on the test set, which is a sign that the model is not over-fitting on the training data.

# %%
train_error = mean_squared_error(y_train, clf.predict(X_train))
test_error = mean_squared_error(y_test, clf.predict(X_test))


print ('The training data MSE is %.3f' % train_error)
print ('The test data MSE is %.3f' % test_error)
# Out:
# The training data MSE is 36.695
# The test data MSE is 31.223

# %% [markdown]
# The coefficient of determination, or R-squared, is the proportion of the variance in the dependent variable (Wins) that is predictable from the independent variables. In sum, it provides a statistic that evaluates how well the model fits the data.  The statistic ranges from 0 to 1 where "1" fits the data perfectly and 0 means that the model explains none of the variability of the response data. For this project, the R-square score when the model is tested against the test data is 0.76 which indicates a high correlation between the number of features and the number of wins.

# %%
# R-square from training and test data

rsquared_train=clf.score(X_train,y_train)
rsquared_test=clf.score(X_test,y_test)
print ('The training data R-square is %.2f' % rsquared_train)
print ('The testing data R-square is %.2f' % rsquared_test)
# Out:
# The training data R-square is 0.72
# The testing data R-square is 0.76

# %% [markdown]
# In the graphic below, the scatter plot compares what the model predicted and what the actual win total was.
#
# The yellow color dots show where the model predicted more wins than the actual total.<br />
# The purple color dots show where the model predicted less wins than the actual total.<br />
# The green color dots show where the model predicted the same or nearly the same as the actual total.

# %%
preds = clf.predict(X_test)
plt.figure(figsize=(10,10))
plt.scatter(preds,  y_test, c=preds-y_test)
plt.ylim(40,120)


plt.xlabel('Model Predictions')
plt.ylabel('Actual Wins')
plt.title('Model One Predictions vs. Actual')
# Out:
# Text(0.5,1,'Model One Predictions vs. Actual')

# %%
for i in range(0, X_test.shape[0]):
    diff = y_test.iloc[i] - preds[i]
    print("The model predicts %d and the actual number is %d. The difference is %d" % (preds[i],y_test.iloc[i], diff))
# Out:
# The model predicts 70 and the actual number is 68. The difference is -2
# The model predicts 64 and the actual number is 67. The difference is 2
# The model predicts 66 and the actual number is 70. The difference is 3
# The model predicts 85 and the actual number is 93. The difference is 7
# The model predicts 86 and the actual number is 87. The difference is 0
# The model predicts 56 and the actual number is 55. The difference is -1
# The model predicts 84 and the actual number is 84. The difference is 0
# The model predicts 84 and the actual number is 90. The difference is 5
# The model predicts 75 and the actual number is 77. The difference is 1
# The model predicts 86 and the actual number is 81. The difference is -5
# The model predicts 96 and the actual number is 96. The difference is 0
# The model predicts 82 and the actual number is 93. The difference is 10
# The model predicts 77 and the actual number is 86. The difference is 8
# The model predicts 97 and the actual number is 93. The difference is -4
# The model predicts 55 and the actual number is 43. The difference is -12
# The model predicts 78 and the actual number is 82. The difference is 3
# The model predicts 73 and the actual number is 65. The difference is -8
# The model predicts 91 and the actual number is 96. The difference is 4
# The model predicts 61 and the actual number is 68. The difference is 6
# The model predicts 70 and the actual number is 67. The difference is -3
# The model predicts 82 and the actual number is 79. The difference is -3
# The model predicts 77 and the actual number is 75. The difference is -2
# The model predicts 80 and the actual number is 75. The difference is -5
# The model predicts 85 and the actual number is 86. The difference is 0
# The model predicts 81 and the actual number is 90. The difference is 8
# The model predicts 74 and the actual number is 81. The difference is 6
# The model predicts 96 and the actual number is 92. The difference is -4
# The model predicts 94 and the actual number is 98. The difference is 3
# The model predicts 76 and the actual number is 69. The difference is -7
# The model predicts 77 and the actual number is 71. The difference is -6
# The model predicts 79 and the actual number is 81. The difference is 1
# The model predicts 87 and the actual number is 97. The difference is 9
# The model predicts 77 and the actual number is 78. The difference is 0
# The model predicts 83 and the actual number is 83. The difference is 0
# The model predicts 97 and the actual number is 95. The difference is -2
# The model predicts 83 and the actual number is 86. The difference is 2
# The model predicts 72 and the actual number is 73. The difference is 0
# The model predicts 88 and the actual number is 82. The difference is -6
# The model predicts 73 and the actual number is 69. The difference is -4
# The model predicts 87 and the actual number is 93. The difference is 5
# The model predicts 72 and the actual number is 65. The difference is -7
# The model predicts 83 and the actual number is 87. The difference is 3
# The model predicts 75 and the actual number is 68. The difference is -7
# The model predicts 81 and the actual number is 82. The difference is 0
# The model predicts 71 and the actual number is 79. The difference is 7
# The model predicts 74 and the actual number is 71. The difference is -3
# The model predicts 91 and the actual number is 89. The difference is -2
# The model predicts 83 and the actual number is 85. The difference is 1
# The model predicts 95 and the actual number is 97. The difference is 1
# The model predicts 85 and the actual number is 90. The difference is 4
# The model predicts 68 and the actual number is 66. The difference is -2
# The model predicts 64 and the actual number is 63. The difference is -1
# The model predicts 77 and the actual number is 72. The difference is -5
# The model predicts 80 and the actual number is 76. The difference is -4
# The model predicts 82 and the actual number is 75. The difference is -7
# The model predicts 91 and the actual number is 92. The difference is 0
# The model predicts 89 and the actual number is 82. The difference is -7
# The model predicts 92 and the actual number is 88. The difference is -4
# The model predicts 75 and the actual number is 81. The difference is 5
# The model predicts 80 and the actual number is 74. The difference is -6
# The model predicts 95 and the actual number is 94. The difference is -1
# The model predicts 80 and the actual number is 91. The difference is 10
# The model predicts 87 and the actual number is 90. The difference is 2
# The model predicts 83 and the actual number is 85. The difference is 1
# The model predicts 89 and the actual number is 87. The difference is -2
# The model predicts 89 and the actual number is 97. The difference is 7
# The model predicts 69 and the actual number is 78. The difference is 8
# The model predicts 62 and the actual number is 62. The difference is 0
# The model predicts 69 and the actual number is 73. The difference is 3
# The model predicts 88 and the actual number is 94. The difference is 5
# The model predicts 70 and the actual number is 70. The difference is 0
# The model predicts 80 and the actual number is 71. The difference is -9
# The model predicts 89 and the actual number is 94. The difference is 4
# The model predicts 82 and the actual number is 79. The difference is -3
# The model predicts 85 and the actual number is 85. The difference is 0
# The model predicts 69 and the actual number is 63. The difference is -6
# The model predicts 78 and the actual number is 88. The difference is 9
# The model predicts 68 and the actual number is 77. The difference is 8
# The model predicts 102 and the actual number is 103. The difference is 0
# The model predicts 77 and the actual number is 87. The difference is 9
# The model predicts 76 and the actual number is 84. The difference is 7
# The model predicts 69 and the actual number is 69. The difference is 0
# The model predicts 92 and the actual number is 101. The difference is 8
# The model predicts 83 and the actual number is 85. The difference is 1
# The model predicts 90 and the actual number is 88. The difference is -2
# The model predicts 77 and the actual number is 78. The difference is 0
# The model predicts 76 and the actual number is 78. The difference is 1
# The model predicts 72 and the actual number is 75. The difference is 2
# The model predicts 96 and the actual number is 87. The difference is -9
# The model predicts 82 and the actual number is 95. The difference is 12
# The model predicts 76 and the actual number is 74. The difference is -2
# The model predicts 93 and the actual number is 96. The difference is 2
# The model predicts 82 and the actual number is 85. The difference is 2
# The model predicts 89 and the actual number is 90. The difference is 0
# The model predicts 71 and the actual number is 71. The difference is 0
# The model predicts 91 and the actual number is 85. The difference is -6
# The model predicts 98 and the actual number is 114. The difference is 15
# The model predicts 71 and the actual number is 74. The difference is 2
# The model predicts 69 and the actual number is 67. The difference is -2
# The model predicts 76 and the actual number is 72. The difference is -4
# The model predicts 68 and the actual number is 74. The difference is 5
# The model predicts 94 and the actual number is 97. The difference is 2
# The model predicts 91 and the actual number is 95. The difference is 3
# The model predicts 78 and the actual number is 68. The difference is -10
# The model predicts 82 and the actual number is 80. The difference is -2
# The model predicts 82 and the actual number is 78. The difference is -4
# The model predicts 97 and the actual number is 102. The difference is 4
# The model predicts 88 and the actual number is 89. The difference is 0
# The model predicts 87 and the actual number is 88. The difference is 0
# The model predicts 83 and the actual number is 89. The difference is 5
# The model predicts 90 and the actual number is 86. The difference is -4
# The model predicts 69 and the actual number is 61. The difference is -8
# The model predicts 65 and the actual number is 64. The difference is -1
# The model predicts 66 and the actual number is 73. The difference is 6
# The model predicts 78 and the actual number is 90. The difference is 11
# The model predicts 91 and the actual number is 86. The difference is -5
# The model predicts 86 and the actual number is 94. The difference is 7
# The model predicts 86 and the actual number is 86. The difference is 0
# The model predicts 67 and the actual number is 66. The difference is -1

# %% [markdown]
# <b>Model One Summary</b><br/>
#
# This model shows that the features that carry the most weight--where weights are greater than or equal to 2-- in terms of predicting wins are listed below. Pitching stats carry more weight than hitting or fielding.  According to this model, the team should prioritize pitchers who excel in these 21 features.

# %%
high_weighted_features = dict(zip( X_train.columns, clf.best_estimator_.coef_))
most_important_features = []
for k,v in high_weighted_features.items():
    if np.absolute(v) >=.01:
        most_important_features.append(k)

most_important_features
# Out:
# ['OFF_PA',
#  'OFF_ISO',
#  'OFF_BABIP',
#  'OFF_AVG',
#  'OFF_wOBA',
#  'OFF_wRC+',
#  'OFF_2B',
#  'OFF_BB',
#  'PITCH_ShO',
#  'PITCH_SV',
#  'PITCH_ER',
#  'PITCH_K/9',
#  'PITCH_K/BB',
#  'PITCH_HR/9',
#  'PITCH_WHIP',
#  'PITCH_LOB%',
#  'PITCH_FIP',
#  'PITCH_Starting',
#  'PITCH_Relieving',
#  'PITCH_Start-IP',
#  'PITCH_Relief-IP',
#  'PITCH_Age']

# %% [markdown]
# #### <a id='7.0'><font color='black'><u>7.0 Model Two: Linear Regression with Deep Neural Network</u></font></a>
#
# The next model that will be used to predict wins is a Deep Learning Neural Network.  Deep Learning is an area of machine learning that mimics animal brains by progressively improving on its ability to learn a task through the use of examples. Input is passed into a network of layers called neurons. Each input is assigned which yields an output. "The DNN finds the correct mathematical manipulation to turn the input into the output, whether it be a linear relationship or a non-linear relationship. The network moves through the layers calculating the probability of each output." (https://en.wikipedia.org/wiki/Deep_learning)
#
# "\[E\]xposed to enough of the right data, deep learning is able to establish correlations between present events and future events. It can run regression between the past and the future."(https://skymind.ai/wiki/neural-network)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from keras.callbacks import ModelCheckpoint  
seed = 7
np.random.seed(seed)
model = Sequential()
model.add(Dense(32, input_dim=40, activation='relu'))
model.add(Dense(units = 32, activation='relu'))
model.add(Dense(units = 32, activation='relu'))
model.add(Dense(units = 32, activation='relu'))
#Output layer
model.add(Dense(units = 1))
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)

model.summary()
# Out:
# Using TensorFlow backend.
# Epoch 1/100
# 475/475 [==============================] - 0s 442us/step - loss: 5957.7763
# Epoch 2/100
# 475/475 [==============================] - 0s 80us/step - loss: 1084.7888
# Epoch 3/100
# 475/475 [==============================] - 0s 80us/step - loss: 125.7383
# Epoch 4/100
# 475/475 [==============================] - 0s 76us/step - loss: 107.3235
# Epoch 5/100
# 475/475 [==============================] - 0s 76us/step - loss: 96.2970
# Epoch 6/100
# 475/475 [==============================] - 0s 73us/step - loss: 85.7795
# Epoch 7/100
# 475/475 [==============================] - 0s 78us/step - loss: 79.9126
# Epoch 8/100
# 475/475 [==============================] - 0s 73us/step - loss: 74.7000
# Epoch 9/100
# 475/475 [==============================] - 0s 71us/step - loss: 70.8742
# Epoch 10/100
# 475/475 [==============================] - 0s 71us/step - loss: 67.7612
# Epoch 11/100
# 475/475 [==============================] - 0s 71us/step - loss: 66.5570
# Epoch 12/100
# 475/475 [==============================] - 0s 71us/step - loss: 65.5420
# Epoch 13/100
# 475/475 [==============================] - 0s 69us/step - loss: 61.7426
# Epoch 14/100
# 475/475 [==============================] - 0s 67us/step - loss: 60.4696
# Epoch 15/100
# 475/475 [==============================] - 0s 69us/step - loss: 60.7285
# Epoch 16/100
# 475/475 [==============================] - 0s 69us/step - loss: 57.7919
# Epoch 17/100
# 475/475 [==============================] - 0s 69us/step - loss: 60.9393
# Epoch 18/100
# 475/475 [==============================] - 0s 71us/step - loss: 55.6047
# Epoch 19/100
# 475/475 [==============================] - 0s 71us/step - loss: 57.0650
# Epoch 20/100
# 475/475 [==============================] - 0s 67us/step - loss: 56.8698
# Epoch 21/100
# 475/475 [==============================] - 0s 71us/step - loss: 52.8317
# Epoch 22/100
# 475/475 [==============================] - 0s 67us/step - loss: 55.1901
# Epoch 23/100
# 475/475 [==============================] - 0s 71us/step - loss: 51.8647
# Epoch 24/100
# 475/475 [==============================] - 0s 69us/step - loss: 49.3494
# Epoch 25/100
# 475/475 [==============================] - 0s 71us/step - loss: 49.9006
# Epoch 26/100
# 475/475 [==============================] - 0s 69us/step - loss: 49.0769
# Epoch 27/100
# 475/475 [==============================] - 0s 69us/step - loss: 47.8121
# Epoch 28/100
# 475/475 [==============================] - 0s 71us/step - loss: 46.9735
# Epoch 29/100
# 475/475 [==============================] - 0s 71us/step - loss: 47.7473
# Epoch 30/100
# 475/475 [==============================] - 0s 65us/step - loss: 46.6122
# Epoch 31/100
# 475/475 [==============================] - 0s 71us/step - loss: 47.9717
# Epoch 32/100
# 475/475 [==============================] - 0s 67us/step - loss: 47.6227
# Epoch 33/100
# 475/475 [==============================] - 0s 69us/step - loss: 50.2658
# Epoch 34/100
# 475/475 [==============================] - 0s 71us/step - loss: 48.8511
# Epoch 35/100
# 475/475 [==============================] - 0s 71us/step - loss: 46.2791
# Epoch 36/100
# 475/475 [==============================] - 0s 69us/step - loss: 46.7091
# Epoch 37/100
# 475/475 [==============================] - 0s 71us/step - loss: 44.7421
# Epoch 38/100
# 475/475 [==============================] - 0s 67us/step - loss: 43.5858
# Epoch 39/100
# 475/475 [==============================] - 0s 69us/step - loss: 45.4319
# Epoch 40/100
# 475/475 [==============================] - 0s 69us/step - loss: 44.0330
# Epoch 41/100
# 475/475 [==============================] - 0s 73us/step - loss: 43.4241
# Epoch 42/100
# 475/475 [==============================] - 0s 69us/step - loss: 46.0582
# Epoch 43/100
# 475/475 [==============================] - 0s 71us/step - loss: 46.6160
# Epoch 44/100
# 475/475 [==============================] - 0s 69us/step - loss: 42.7076
# Epoch 45/100
# 475/475 [==============================] - 0s 69us/step - loss: 43.6315
# Epoch 46/100
# 475/475 [==============================] - 0s 71us/step - loss: 43.5155
# Epoch 47/100
# 475/475 [==============================] - 0s 71us/step - loss: 43.1064
# Epoch 48/100
# 475/475 [==============================] - 0s 69us/step - loss: 41.6256
# Epoch 49/100
# 475/475 [==============================] - 0s 73us/step - loss: 46.0305
# Epoch 50/100
# 475/475 [==============================] - 0s 71us/step - loss: 41.8932
# Epoch 51/100
# 475/475 [==============================] - 0s 69us/step - loss: 43.7872
# Epoch 52/100
# 475/475 [==============================] - 0s 69us/step - loss: 42.0314
# Epoch 53/100
# 475/475 [==============================] - 0s 69us/step - loss: 41.0632
# Epoch 54/100
# 475/475 [==============================] - 0s 69us/step - loss: 41.6139
# Epoch 55/100
# 475/475 [==============================] - 0s 69us/step - loss: 43.5768
# Epoch 56/100
# 475/475 [==============================] - 0s 71us/step - loss: 40.4438
# Epoch 57/100
# 475/475 [==============================] - 0s 69us/step - loss: 45.0944
# Epoch 58/100
# 475/475 [==============================] - 0s 71us/step - loss: 40.2951
# Epoch 59/100
# 475/475 [==============================] - 0s 69us/step - loss: 41.2564
# Epoch 60/100
# 475/475 [==============================] - 0s 69us/step - loss: 40.4852
# Epoch 61/100
# 475/475 [==============================] - 0s 65us/step - loss: 40.3309
# Epoch 62/100
# 475/475 [==============================] - 0s 71us/step - loss: 40.6354
# Epoch 63/100
# 475/475 [==============================] - 0s 67us/step - loss: 40.8757
# Epoch 64/100
# 475/475 [==============================] - 0s 67us/step - loss: 39.8326
# Epoch 65/100
# 475/475 [==============================] - 0s 67us/step - loss: 40.6252
# Epoch 66/100
# 475/475 [==============================] - 0s 71us/step - loss: 40.4490
# Epoch 67/100
# 475/475 [==============================] - 0s 71us/step - loss: 40.8270
# Epoch 68/100
# 475/475 [==============================] - 0s 71us/step - loss: 41.7939
# Epoch 69/100
# 475/475 [==============================] - 0s 67us/step - loss: 39.8239
# Epoch 70/100
# 475/475 [==============================] - 0s 67us/step - loss: 41.9782
# Epoch 71/100
# 475/475 [==============================] - 0s 67us/step - loss: 40.0652
# Epoch 72/100
# 475/475 [==============================] - 0s 69us/step - loss: 40.3825
# Epoch 73/100
# 475/475 [==============================] - 0s 69us/step - loss: 42.1513
# Epoch 74/100
# 475/475 [==============================] - 0s 67us/step - loss: 38.4655
# Epoch 75/100
# 475/475 [==============================] - 0s 67us/step - loss: 39.9395
# Epoch 76/100
# 475/475 [==============================] - 0s 67us/step - loss: 40.5445
# Epoch 77/100
# 475/475 [==============================] - 0s 67us/step - loss: 39.3446
# Epoch 78/100
# 475/475 [==============================] - 0s 67us/step - loss: 39.1677
# Epoch 79/100
# 475/475 [==============================] - 0s 67us/step - loss: 38.2918
# Epoch 80/100
# 475/475 [==============================] - 0s 67us/step - loss: 40.5929
# Epoch 81/100
# 475/475 [==============================] - 0s 65us/step - loss: 40.3928
# Epoch 82/100
# 475/475 [==============================] - 0s 67us/step - loss: 39.7212
# Epoch 83/100
# 475/475 [==============================] - 0s 67us/step - loss: 38.7622
# Epoch 84/100
# 475/475 [==============================] - 0s 65us/step - loss: 40.9308
# Epoch 85/100
# 475/475 [==============================] - 0s 67us/step - loss: 44.2587
# Epoch 86/100
# 475/475 [==============================] - 0s 65us/step - loss: 39.2192
# Epoch 87/100
# 475/475 [==============================] - 0s 67us/step - loss: 40.5960
# Epoch 88/100
# 475/475 [==============================] - 0s 67us/step - loss: 41.8478
# Epoch 89/100
# 475/475 [==============================] - 0s 69us/step - loss: 38.0842
# Epoch 90/100
# 475/475 [==============================] - 0s 67us/step - loss: 38.0870
# Epoch 91/100
# 475/475 [==============================] - 0s 67us/step - loss: 43.2491
# Epoch 92/100
# 475/475 [==============================] - 0s 67us/step - loss: 38.4764
# Epoch 93/100
# 475/475 [==============================] - 0s 65us/step - loss: 38.4414
# Epoch 94/100
# 475/475 [==============================] - 0s 67us/step - loss: 41.3267
# Epoch 95/100
# 475/475 [==============================] - 0s 67us/step - loss: 38.0185
# Epoch 96/100
# 475/475 [==============================] - 0s 67us/step - loss: 39.1582
# Epoch 97/100
# 475/475 [==============================] - 0s 67us/step - loss: 37.9456
# Epoch 98/100
# 475/475 [==============================] - 0s 69us/step - loss: 37.7664
# Epoch 99/100
# 475/475 [==============================] - 0s 67us/step - loss: 38.1334
# Epoch 100/100
# 475/475 [==============================] - 0s 67us/step - loss: 39.7695
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                1312
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 4,513
# Trainable params: 4,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
preds2 = model.predict(X_test)
preds2 = list(preds2[:,0])
diff =[]
for i in range(0, X_test.shape[0]):
    diff.append(preds2[i]- y_test.iloc[i])
    print("The model predicts %d and the actual number is %d. The difference is %d" % (preds2[i],y_test.iloc[i], diff[i]))
# Out:
# The model predicts 68 and the actual number is 68. The difference is 0
# The model predicts 64 and the actual number is 67. The difference is -2
# The model predicts 65 and the actual number is 70. The difference is -4
# The model predicts 83 and the actual number is 93. The difference is -9
# The model predicts 85 and the actual number is 87. The difference is -1
# The model predicts 57 and the actual number is 55. The difference is 2
# The model predicts 82 and the actual number is 84. The difference is -1
# The model predicts 84 and the actual number is 90. The difference is -5
# The model predicts 74 and the actual number is 77. The difference is -2
# The model predicts 87 and the actual number is 81. The difference is 6
# The model predicts 94 and the actual number is 96. The difference is -1
# The model predicts 81 and the actual number is 93. The difference is -11
# The model predicts 77 and the actual number is 86. The difference is -8
# The model predicts 94 and the actual number is 93. The difference is 1
# The model predicts 53 and the actual number is 43. The difference is 10
# The model predicts 77 and the actual number is 82. The difference is -4
# The model predicts 72 and the actual number is 65. The difference is 7
# The model predicts 90 and the actual number is 96. The difference is -5
# The model predicts 61 and the actual number is 68. The difference is -6
# The model predicts 68 and the actual number is 67. The difference is 1
# The model predicts 81 and the actual number is 79. The difference is 2
# The model predicts 76 and the actual number is 75. The difference is 1
# The model predicts 80 and the actual number is 75. The difference is 5
# The model predicts 81 and the actual number is 86. The difference is -4
# The model predicts 78 and the actual number is 90. The difference is -11
# The model predicts 70 and the actual number is 81. The difference is -10
# The model predicts 95 and the actual number is 92. The difference is 3
# The model predicts 93 and the actual number is 98. The difference is -4
# The model predicts 76 and the actual number is 69. The difference is 7
# The model predicts 77 and the actual number is 71. The difference is 6
# The model predicts 78 and the actual number is 81. The difference is -2
# The model predicts 87 and the actual number is 97. The difference is -9
# The model predicts 74 and the actual number is 78. The difference is -3
# The model predicts 81 and the actual number is 83. The difference is -1
# The model predicts 96 and the actual number is 95. The difference is 1
# The model predicts 79 and the actual number is 86. The difference is -6
# The model predicts 70 and the actual number is 73. The difference is -2
# The model predicts 85 and the actual number is 82. The difference is 3
# The model predicts 70 and the actual number is 69. The difference is 1
# The model predicts 86 and the actual number is 93. The difference is -6
# The model predicts 69 and the actual number is 65. The difference is 4
# The model predicts 81 and the actual number is 87. The difference is -5
# The model predicts 72 and the actual number is 68. The difference is 4
# The model predicts 78 and the actual number is 82. The difference is -3
# The model predicts 70 and the actual number is 79. The difference is -8
# The model predicts 74 and the actual number is 71. The difference is 3
# The model predicts 90 and the actual number is 89. The difference is 1
# The model predicts 83 and the actual number is 85. The difference is -1
# The model predicts 94 and the actual number is 97. The difference is -2
# The model predicts 83 and the actual number is 90. The difference is -6
# The model predicts 68 and the actual number is 66. The difference is 2
# The model predicts 62 and the actual number is 63. The difference is 0
# The model predicts 76 and the actual number is 72. The difference is 4
# The model predicts 79 and the actual number is 76. The difference is 3
# The model predicts 82 and the actual number is 75. The difference is 7
# The model predicts 90 and the actual number is 92. The difference is -1
# The model predicts 87 and the actual number is 82. The difference is 5
# The model predicts 90 and the actual number is 88. The difference is 2
# The model predicts 72 and the actual number is 81. The difference is -8
# The model predicts 79 and the actual number is 74. The difference is 5
# The model predicts 91 and the actual number is 94. The difference is -2
# The model predicts 78 and the actual number is 91. The difference is -12
# The model predicts 84 and the actual number is 90. The difference is -5
# The model predicts 81 and the actual number is 85. The difference is -3
# The model predicts 87 and the actual number is 87. The difference is 0
# The model predicts 86 and the actual number is 97. The difference is -10
# The model predicts 67 and the actual number is 78. The difference is -10
# The model predicts 60 and the actual number is 62. The difference is -1
# The model predicts 67 and the actual number is 73. The difference is -5
# The model predicts 87 and the actual number is 94. The difference is -6
# The model predicts 68 and the actual number is 70. The difference is -1
# The model predicts 77 and the actual number is 71. The difference is 6
# The model predicts 88 and the actual number is 94. The difference is -5
# The model predicts 79 and the actual number is 79. The difference is 0
# The model predicts 84 and the actual number is 85. The difference is 0
# The model predicts 66 and the actual number is 63. The difference is 3
# The model predicts 77 and the actual number is 88. The difference is -10
# The model predicts 66 and the actual number is 77. The difference is -10
# The model predicts 100 and the actual number is 103. The difference is -2
# The model predicts 75 and the actual number is 87. The difference is -11
# The model predicts 75 and the actual number is 84. The difference is -8
# The model predicts 67 and the actual number is 69. The difference is -1
# The model predicts 91 and the actual number is 101. The difference is -9
# The model predicts 80 and the actual number is 85. The difference is -4
# The model predicts 89 and the actual number is 88. The difference is 1
# The model predicts 77 and the actual number is 78. The difference is 0
# The model predicts 74 and the actual number is 78. The difference is -3
# The model predicts 69 and the actual number is 75. The difference is -5
# The model predicts 95 and the actual number is 87. The difference is 8
# The model predicts 80 and the actual number is 95. The difference is -14
# The model predicts 75 and the actual number is 74. The difference is 1
# The model predicts 90 and the actual number is 96. The difference is -5
# The model predicts 82 and the actual number is 85. The difference is -2
# The model predicts 86 and the actual number is 90. The difference is -3
# The model predicts 69 and the actual number is 71. The difference is -1
# The model predicts 88 and the actual number is 85. The difference is 3
# The model predicts 96 and the actual number is 114. The difference is -17
# The model predicts 68 and the actual number is 74. The difference is -5
# The model predicts 68 and the actual number is 67. The difference is 1
# The model predicts 75 and the actual number is 72. The difference is 3
# The model predicts 66 and the actual number is 74. The difference is -7
# The model predicts 91 and the actual number is 97. The difference is -5
# The model predicts 88 and the actual number is 95. The difference is -6
# The model predicts 76 and the actual number is 68. The difference is 8
# The model predicts 79 and the actual number is 80. The difference is 0
# The model predicts 80 and the actual number is 78. The difference is 2
# The model predicts 95 and the actual number is 102. The difference is -6
# The model predicts 88 and the actual number is 89. The difference is 0
# The model predicts 83 and the actual number is 88. The difference is -4
# The model predicts 81 and the actual number is 89. The difference is -7
# The model predicts 88 and the actual number is 86. The difference is 2
# The model predicts 68 and the actual number is 61. The difference is 7
# The model predicts 63 and the actual number is 64. The difference is 0
# The model predicts 66 and the actual number is 73. The difference is -6
# The model predicts 76 and the actual number is 90. The difference is -13
# The model predicts 90 and the actual number is 86. The difference is 4
# The model predicts 84 and the actual number is 94. The difference is -9
# The model predicts 84 and the actual number is 86. The difference is -1
# The model predicts 64 and the actual number is 66. The difference is -1

# %%
mse = [i ** 2 for i in diff]

print("The Mean Squared Error for this model is %.2f" % np.mean(mse))
# Out:
# The Mean Squared Error for this model is 36.66

# %%
plt.figure(figsize=(10,10))
plt.scatter(preds2, y_test, c=preds2-y_test)
plt.xlabel('Model Predictions')
plt.ylabel('Actual Wins')
plt.title('Model Two Predictions vs. Actual')
# Out:
# Text(0.5,1,'Model Two Predictions vs. Actual')

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, preds2)
print('The R square score of the Deep Neural Network models is %.2f' % score)
# Out:
# The R square score of the Deep Neural Network models is 0.72

# %% [markdown]
# <b>Model Two Summary</b><br/>
#
# Model Two confirms the results that were discovered in Model One. The Mean Squared Error on the test data for this model is 37 whereas the MSE for the previous model was 32 which confirms the 21 most important features.

# %% [markdown]
# <b>Model Performance on Unseen Data</b><br/>

# %%
import capstoneutils as cp

for i in range(0,3):
    csvPath = path + "\\FINAL DATASET version 1.0\\2018 TEST DATA\Source\\"
    Test_2018_MLB_Stats_df = pd.DataFrame()
    print(csvPath)
    Test_2018_MLB_Stats_df  = cp.mergeCSVs(csvPath, "Test_2018_MLB_Stats.csv", path + r"\FINAL DATASET version 1.0\2018 TEST DATA\Output")
# Out:
# C:\Users\jkhan\Documents\udacity\MLND\Capstone Project\CAPSTONE FINAL PROJECT\01_The Model\FINAL DATASET version 1.0\2018 TEST DATA\Source\
# C:\Users\jkhan\Documents\udacity\MLND\Capstone Project\CAPSTONE FINAL PROJECT\01_The Model\FINAL DATASET version 1.0\2018 TEST DATA\Source\
# C:\Users\jkhan\Documents\udacity\MLND\Capstone Project\CAPSTONE FINAL PROJECT\01_The Model\FINAL DATASET version 1.0\2018 TEST DATA\Source\

# %%
Test_2018_MLB_Stats_df = Test_2018_MLB_Stats_df.loc[:,~Test_2018_MLB_Stats_df.columns.duplicated()]
Team_Wins = (Test_2018_MLB_Stats_df['Team'],Test_2018_MLB_Stats_df['W'])
Features_2018_df = Test_2018_MLB_Stats_df.drop(['Team','W'], axis=1)
Features_2018_df = Features_2018_df.applymap(cp.remove_percentages)
numerical = Features_2018_df .columns.values.tolist()
Features_2018_df[numerical] = scaler.fit_transform(Features_2018_df[numerical])
# # len(Features_2018_df.columns.values)
# X_test.columns.values

# %%
##Model One
preds_2018 = clf.predict(Features_2018_df)
preds_2018 = preds_2018*.83
actual_wins = Team_Wins[1]
team = Team_Wins[0]
for i in range(0, len(actual_wins)):
    diff = actual_wins[i] - preds_2018[i]
    print("The model predicts %d and the actual number is %d. The difference is %d. The team is %s." % (preds_2018[i],actual_wins[i], diff, team[i]))
# Out:
# The model predicts 97 and the actual number is 82. The difference is -15. The team is Astros.
# The model predicts 98 and the actual number is 72. The difference is -26. The team is Dodgers.
# The model predicts 80 and the actual number is 73. The difference is -7. The team is Diamondbacks.
# The model predicts 89 and the actual number is 92. The difference is 2. The team is Red Sox.
# The model predicts 71 and the actual number is 74. The difference is 2. The team is Cardinals.
# The model predicts 95 and the actual number is 84. The difference is -11. The team is Yankees.
# The model predicts 79 and the actual number is 71. The difference is -8. The team is Rays.
# The model predicts 59 and the actual number is 78. The difference is 18. The team is Cubs.
# The model predicts 64 and the actual number is 74. The difference is 9. The team is Braves.
# The model predicts 49 and the actual number is 80. The difference is 30. The team is Athletics.
# The model predicts 76 and the actual number is 67. The difference is -9. The team is Giants.
# The model predicts 84 and the actual number is 75. The difference is -9. The team is Indians.
# The model predicts 75 and the actual number is 71. The difference is -4. The team is Phillies.
# The model predicts 76 and the actual number is 67. The difference is -9. The team is Nationals.
# The model predicts 63 and the actual number is 74. The difference is 10. The team is Brewers.
# The model predicts 60 and the actual number is 65. The difference is 4. The team is Pirates.
# The model predicts 71 and the actual number is 64. The difference is -7. The team is Angels.
# The model predicts 62 and the actual number is 74. The difference is 11. The team is Mariners.
# The model predicts 62 and the actual number is 59. The difference is -3. The team is Mets.
# The model predicts 68 and the actual number is 52. The difference is -16. The team is Padres.
# The model predicts 74 and the actual number is 62. The difference is -12. The team is Twins.
# The model predicts 63 and the actual number is 53. The difference is -10. The team is Tigers.
# The model predicts 63 and the actual number is 72. The difference is 8. The team is Rockies.
# The model predicts 58 and the actual number is 53. The difference is -5. The team is Marlins.
# The model predicts 45 and the actual number is 53. The difference is 7. The team is White Sox.
# The model predicts 41 and the actual number is 57. The difference is 15. The team is Reds.
# The model predicts 53 and the actual number is 60. The difference is 6. The team is Blue Jays.
# The model predicts 39 and the actual number is 58. The difference is 18. The team is Rangers.
# The model predicts 49 and the actual number is 40. The difference is -9. The team is Orioles.
# The model predicts 44 and the actual number is 42. The difference is -2. The team is Royals.

# %%
score = r2_score( actual_wins, preds_2018)
print('The R square score of Model One is %.2f' % score)
# Out:
# The R square score of Model One is -0.08

# %%
test_mse = mean_squared_error(actual_wins, clf.predict(Features_2018_df))
test_mse
# Out:
# 433.8693930090151

# %% [markdown]
# <b><u>Comparison to the Pythagorean Theorem of Baseball</u></b>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

#Comparison to the Pythagorean
model1_predictions = model.predict(X_train.ix[[510]]).tolist()[0][0]
model2_predictions = clf.predict(X_train.ix[[510]])[0]
print("For the team that allowed the least amount of runs, the LASSO model predicted %.0f wins." % model1_predictions)
print("For the team that allowed the least amount of runs, the Deep Neural Networks model predicted %.0f wins." % model2_predictions)

Max_Runs_Scored = Final_MLB_Data.ix[[30]]
Max_Runs_Scored.drop(['W'], axis=1)
Max_Runs_Scored=Max_Runs_Scored[feats]

numerical = Max_Runs_Scored.columns.values.tolist()
Max_Runs_Scored[numerical] = scaler.fit_transform(Max_Runs_Scored[numerical])
print(model.predict(Max_Runs_Scored))
print(clf.predict(Max_Runs_Scored))
# Out:
# For the team that allowed the least amount of runs, the LASSO model predicted 98 wins.
# For the team that allowed the least amount of runs, the Deep Neural Networks model predicted 100 wins.
# [[18.352304]]
# [37.82265239]

# %% [markdown]
# #### <a id='8.0'><font color='black'><u>8.0 Hitters Hierarchial Clustering</u></font></a>
#
# With the knowledge of the number of features, the project will now turn to cluster analysis of the current players. For this project, we want hierarchial clusters of the players since the goal is to target players whose statistics are a better match for the features that we have discovered in the models. With the knowledge of the number of features, the project will now turn to cluster analysis of the current players. For this project, we want hierarchical clusters of the players since the goal is to target players whose statistics are a better match for the features that we have discovered in the models.  Hierarchical clustering starts out with each observation as its own cluster. It then identifies each cluster that is closest together and merges similar clusters until all clusters are merged into one cluster.
#
#
# For the sake of brevity, the project will focus only on the segments for hitters.

# %%
path = os.chdir('..')
path = os.chdir('..')
print(os.getcwd())
Player_Hitting_Data = pd.read_csv('2018 Hitting Pitching Stats Players.csv')
Player_Fielding_Data = pd.read_csv('2018 Fielding Stats Players.csv')
# Out:
# C:\Users\jkhan\Documents\udacity\MLND\Capstone Project\CAPSTONE FINAL PROJECT\01_The Model\FINAL DATASET version 1.0

# %%
Player_Hit_Field_Data = pd.merge(Player_Hitting_Data, Player_Fielding_Data[['FP','playerid']], how='left', on='playerid')
Player_Hit_Field_Data = Player_Hit_Field_Data.drop_duplicates(['playerid'])
Player_Hit_Field_Data[Player_Hit_Field_Data.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Name, Team, PA, HR, R, RBI, ISO, BABIP, AVG, OBP, SLG, wOBA, wRC+, H, 2B, playerid, FP]
# Index: []

# %%
Player_Hit_Field_Data[Player_Hit_Field_Data['FP'].isnull()]
# Out:
#                 Name      Team   PA  HR   R  RBI    ISO  BABIP    AVG    OBP  \
# 31       Nelson Cruz  Mariners  446  30  52   78  0.269  0.268  0.267  0.354
# 133      Evan Gattis    Astros  387  23  45   70  0.247  0.239  0.236  0.295
# 213  Victor Martinez    Tigers  414   6  25   41  0.090  0.259  0.248  0.300
#
#        SLG   wOBA  wRC+    H  2B  playerid  FP
# 31   0.536  0.376   143  104  13      2434 NaN
# 133  0.483  0.326   109   82  17     11003 NaN
# 213  0.338  0.277    70   94  16       393 NaN

# %%
Player_Hit_Field_Data = Player_Hit_Field_Data.drop([31,133,213])

# %%
#Select the 21 most important features for hitting
Player_Hit_Field_Data=Player_Hit_Field_Data.loc[:,['Team','Name','playerid','FP', 'PA', 'ISO', 'BABIP', 'AVG', 'wOBA', 'wRC+', '2B']]

Player_Hit_Field_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 221
# Data columns (total 11 columns):
# Team        150 non-null object
# Name        150 non-null object
# playerid    150 non-null int64
# FP          150 non-null float64
# PA          150 non-null int64
# ISO         150 non-null float64
# BABIP       150 non-null float64
# AVG         150 non-null float64
# wOBA        150 non-null float64
# wRC+        150 non-null int64
# 2B          150 non-null int64
# dtypes: float64(5), int64(4), object(2)
# memory usage: 14.1+ KB

# %%
Player_Hit_Field_Data2 = Player_Hit_Field_Data.drop(['Name','Team'], axis=1)

# %%
pd.scatter_matrix(Player_Hit_Field_Data2.iloc[:,1:8], alpha = 0.3, figsize = (14,8), diagonal = 'kde');

# %%
Player_Hit_Field_Data2.iloc[:,1:8]= np.log(Player_Hit_Field_Data2.iloc[:,1:8])

# Produce a scatter matrix for each pair of newly-transformed features
pd.scatter_matrix(Player_Hit_Field_Data2.iloc[:,1:8], alpha = 0.3, figsize = (14,8), diagonal = 'kde');

# %%
cnt = collections.Counter()
cnt = hp.detect_outliers(Player_Hit_Field_Data2.iloc[:,1:8])
outliers  = [list(cnt.keys())]
# Out:
# Data points considered outliers for the feature 'FP':
#            FP        PA       ISO     BABIP       AVG      wOBA      wRC+
# 14  -0.055513  6.133398 -1.374366 -1.093625 -1.217396 -0.944176  4.969813
# 18  -0.054456  6.295266 -1.439695 -1.272966 -1.283738 -0.957113  5.003946
# 27  -0.051293  6.285998 -1.629641 -1.055553 -1.269401 -0.975510  4.912655
# 44  -0.060812  6.109248 -1.452434 -1.117795 -1.203973 -1.005122  4.882802
# 110 -0.058689  6.056784 -1.418818 -1.167962 -1.418818 -1.099613  4.691348
# 141 -0.060812  6.180017 -1.877317 -1.152013 -1.255266 -1.123930  4.644391
# 178 -0.073647  6.047372 -1.714798 -1.241329 -1.418818 -1.180908  4.488636
# Data points considered outliers for the feature 'PA':
# Empty DataFrame
# Columns: [FP, PA, ISO, BABIP, AVG, wOBA, wRC+]
# Index: []
# Data points considered outliers for the feature 'ISO':
#            FP        PA       ISO     BABIP       AVG      wOBA      wRC+
# 214 -0.022246  6.175867 -2.718101 -1.158362 -1.298283 -1.283738  4.317488
# Data points considered outliers for the feature 'BABIP':
# Empty DataFrame
# Columns: [FP, PA, ISO, BABIP, AVG, wOBA, wRC+]
# Index: []
# Data points considered outliers for the feature 'AVG':
#            FP        PA       ISO    BABIP       AVG      wOBA      wRC+
# 221 -0.006018  6.040255 -1.937942 -1.52326 -1.820159 -1.418818  3.850148
# Data points considered outliers for the feature 'wOBA':
#            FP        PA       ISO     BABIP       AVG      wOBA      wRC+
# 0   -0.005013  6.163315 -1.164752 -1.030019 -1.061317 -0.791863  5.241747
# 219 -0.023269  6.079933 -2.525729 -1.448170 -1.570217 -1.414694  3.850148
# 221 -0.006018  6.040255 -1.937942 -1.523260 -1.820159 -1.418818  3.850148
# Data points considered outliers for the feature 'wRC+':
#            FP        PA       ISO     BABIP       AVG      wOBA      wRC+
# 217 -0.017146  5.996452 -2.263364 -1.244795 -1.491655 -1.347074  4.077537
# 219 -0.023269  6.079933 -2.525729 -1.448170 -1.570217 -1.414694  3.850148
# 221 -0.006018  6.040255 -1.937942 -1.523260 -1.820159 -1.418818  3.850148

# %%
cnt.most_common()
# Out:
# [(221, 3),
#  (219, 2),
#  (14, 1),
#  (18, 1),
#  (27, 1),
#  (44, 1),
#  (110, 1),
#  (141, 1),
#  (178, 1),
#  (214, 1),
#  (0, 1),
#  (217, 1)]

# %%
Player_Hit_Field_Data2 = Player_Hit_Field_Data2.drop([221,219])

# %%
import seaborn as sns
sns.boxplot(Player_Hit_Field_Data2['wOBA'])

# %%
numerical2 = Player_Hit_Field_Data2.loc[: ,['FP','PA','ISO','BABIP','AVG','wOBA','wRC+','2B']].columns.values.tolist()
Player_Hit_Field_Data[numerical2] = scaler.fit_transform(Player_Hit_Field_Data[numerical2])

# %%
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))  
plt.title("Hitters Dendograms")  
dend = shc.dendrogram(shc.linkage(Player_Hit_Field_Data2.iloc[:,1:8], method='complete'))

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=2 , affinity='euclidean', linkage='complete')  
preds = cluster.fit_predict(Player_Hit_Field_Data2.iloc[:,1:8])

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score(Player_Hit_Field_Data2,preds)
print(score)
# Out:
# 0.03518217029517602

# %%
Player_Hit_Field_Data2['cluster'] = preds

# %%
Player_Hit_Field_Data = pd.merge(Player_Hitting_Data, Player_Hit_Field_Data2[['cluster','playerid']], how='left', on='playerid')
cluster1 = Player_Hit_Field_Data[Player_Hit_Field_Data['cluster']==1.0]
cluster0 = Player_Hit_Field_Data[Player_Hit_Field_Data['cluster']==0.0]

# %% [markdown]
# <font color='black'><b><u>Summary of Hitters Segment Analysis</u></b></font>
#
# The segment analysis of the hitters shows that the hitters can be separated largely into two clusters, cluster 0 and cluster 1.  Hitters in cluster 0 are the ones that the team should target in order to meet the features that lead to wins. Earlier, the models showed that the hitting feature with the most weight is weighted on-base average ("wOBA").  In the tables below, you see that hitters in cluster 0 have a mean wOBA of 35% while those in cluster 0 have a mean wOBA of 31%.  The other significant offensive statistic that weighs heavily is the weighted Runs Created("wRC+").  Cluster 0 has a mean of 119 wRC+ while cluster 1 has a mean of 95 wRC+.

# %%
#cluster 0 statistics
cluster0.describe()
# Out:
#                PA          HR           R         RBI         ISO       BABIP  \
# count  119.000000  119.000000  119.000000  119.000000  119.000000  119.000000
# mean   465.991597   18.193277   60.907563   60.436975    0.200353    0.300630
# std     44.644831    6.881906   13.362604   14.445478    0.046810    0.034885
# min    386.000000    5.000000   39.000000   35.000000    0.121000    0.223000
# 25%    426.500000   14.000000   51.000000   49.000000    0.168000    0.274500
# 50%    466.000000   18.000000   60.000000   60.000000    0.196000    0.301000
# 75%    498.500000   22.000000   69.000000   70.000000    0.226500    0.326500
# max    567.000000   38.000000  102.000000  106.000000    0.335000    0.378000
#
#               AVG         OBP         SLG        wOBA        wRC+           H  \
# count  119.000000  119.000000  119.000000  119.000000  119.000000  119.000000
# mean     0.264445    0.337513    0.464782    0.342655  114.932773  109.773109
# std      0.028067    0.035022    0.062861    0.035366   23.542148   17.689620
# min      0.199000    0.262000    0.357000    0.280000   75.000000   71.000000
# 25%      0.242500    0.315500    0.416000    0.316500   96.500000   95.500000
# 50%      0.265000    0.334000    0.464000    0.339000  113.000000  106.000000
# 75%      0.283000    0.359000    0.499000    0.363500  129.000000  122.000000
# max      0.346000    0.459000    0.667000    0.453000  190.000000  152.000000
#
#                2B      playerid  cluster
# count  119.000000    119.000000    119.0
# mean    23.932773  10534.521008      0.0
# std      6.525999   4199.765677      0.0
# min     10.000000   1177.000000      0.0
# 25%     20.000000   6946.000000      0.0
# 50%     23.000000  11342.000000      0.0
# 75%     27.500000  13256.000000      0.0
# max     43.000000  19198.000000      0.0

# %%
#cluster 1 statistics
cluster1.describe()
# Out:
#                PA        HR          R        RBI        ISO      BABIP  \
# count   29.000000  29.00000  29.000000  29.000000  29.000000  29.000000
# mean   469.827586   7.37931  56.137931  41.379310   0.111241   0.320207
# std     54.624085   3.39552  11.918545  10.665076   0.020028   0.025435
# min    389.000000   2.00000  34.000000  24.000000   0.066000   0.274000
# 25%    420.000000   5.00000  47.000000  32.000000   0.101000   0.302000
# 50%    464.000000   7.00000  57.000000  40.000000   0.114000   0.317000
# 75%    522.000000   9.00000  65.000000  49.000000   0.125000   0.334000
# max    557.000000  15.00000  78.000000  67.000000   0.145000   0.375000
#
#              AVG        OBP        SLG       wOBA        wRC+           H  \
# count  29.000000  29.000000  29.000000  29.000000   29.000000   29.000000
# mean    0.274724   0.337621   0.386069   0.316621   98.689655  116.517241
# std     0.024517   0.034624   0.036804   0.028211   19.482783   17.634424
# min     0.225000   0.266000   0.306000   0.260000   59.000000   84.000000
# 25%     0.257000   0.316000   0.355000   0.295000   83.000000  103.000000
# 50%     0.277000   0.336000   0.390000   0.317000   98.000000  120.000000
# 75%     0.292000   0.357000   0.416000   0.331000  109.000000  129.000000
# max     0.329000   0.422000   0.464000   0.372000  139.000000  148.000000
#
#               2B      playerid  cluster
# count  29.000000     29.000000     29.0
# mean   20.206897   9476.103448      1.0
# std     5.354433   4488.372902      0.0
# min     9.000000   1857.000000      1.0
# 25%    18.000000   5417.000000      1.0
# 50%    20.000000   9166.000000      1.0
# 75%    24.000000  13593.000000      1.0
# max    32.000000  18289.000000      1.0

# %%
cluster0.head(10)
# Out:
#                Name          Team   PA  HR    R  RBI    ISO  BABIP    AVG  \
# 0      Mookie Betts       Red Sox  475  27  100   64  0.312  0.357  0.346
# 1        Mike Trout        Angels  482  30   82   60  0.315  0.343  0.309
# 2     J.D. Martinez       Red Sox  507  38   92  106  0.333  0.375  0.333
# 3      Jose Ramirez       Indians  531  37   85   91  0.335  0.274  0.301
# 4     Nolan Arenado       Rockies  504  30   80   85  0.270  0.328  0.309
# 5       Aaron Judge       Yankees  447  26   70   61  0.263  0.377  0.285
# 6  Paul Goldschmidt  Diamondbacks  544  28   78   71  0.254  0.360  0.293
# 7    Matt Carpenter     Cardinals  518  33   83   68  0.306  0.290  0.269
# 8   Freddie Freeman        Braves  542  20   76   77  0.210  0.367  0.320
# 9     Jesus Aguilar       Brewers  413  29   61   89  0.299  0.310  0.280
#
#      OBP    SLG   wOBA  wRC+    H  2B  playerid  cluster
# 0  0.434  0.658  0.453   189  141  36     13611      0.0
# 1  0.459  0.624  0.445   190  115  21     10155      0.0
# 2  0.404  0.667  0.444   182  149  33      6184      0.0
# 3  0.412  0.636  0.432   176  133  31     13510      0.0
# 4  0.391  0.580  0.408   142  136  25      9777      0.0
# 5  0.398  0.548  0.401   156  106  20     15640      0.0
# 6  0.397  0.547  0.400   152  136  26      9218      0.0
# 7  0.386  0.575  0.398   153  116  33      8090      0.0
# 8  0.402  0.530  0.394   149  151  33      5361      0.0
# 9  0.366  0.579  0.394   146   99  19     11342      0.0

# %% [markdown]
# Player to target: <b>Nolan Arenado, 3B Colorado Rockies</b>
# <br />
# <img src="Arenado.jpg" align="left"  height="100" width="100" /><br />
# <br />
#
# Perhaps a top player to target is Colorado Rockies 3B, Nolan Arenado who will be free agent in 2020.

# %% [markdown]
# #### <a id='9.0'><font color=black><u>9.0 Final Summary </u></font></a>
#
# Over the last 20 years, teams in MLB have a 14% chance of winning 95 games or more in a season.  This report started off with over 600 features which were reduced to  showed that the key offensive features that the team needs to have are the following:
#
# <ol>
# <li>Field Percentage ('FP'): Fielding percentage: The percentage of times a defensive player properly handles a batted or thrown ball.</li><br />
# <li>Plate Appearance ('PA'): Number of plate appearances.</li><br />
# <li>Isolated Power ('ISO'): Average number of extra bases per at bat, calculated several ways such as SLG minus AVG.</li><br />
# <li>Batted Balls in Play ('BABIP'):The rate at which the batter gets a hit when he puts the ball in play.</li><br />
# <li>Average('AVG'): Rate of hits per at bat, calculated as H/AB.</li><br />
# <li>Weighted On Base Average('wOBA'):  Is a statistic, based on linear weights,designed to measure a player's overall offensive contributions per plate appearance. It is formed from taking the observed run values of various offensive events, dividing by a player's plate appearances, and scaling the result to be on the same scale as on-base percentage. </li><br />
# <li>Weighted Runs Created plus('wRC+'): Quantifies a player’s total offensive value and measure it by runs. It synthesizes all of a players offensive stats and applies a formula to those stats to quantify how many runs a player is worth to his team in comparison to the league average.  Nolan Arenado's wRC+ is 142 which means that he created 42% more runs than the league average.</li><br />
# <li>Doubles('2B'): Total number of doubles.</li><br />
# </ol>
#
#
# There are limitations to this analysis.  One, the low number of observations may have an impact the analysis. We cannot determine if there's enough data to build a completely accurate model.  However, there's no way to add more observations.  Going back further than 1998 is also problematic as the number of teams per year may impact the number of wins.  Two, some of the features gathered from fangraphs are not complete for the entirety of the years.  There's a lot of fielding data that was not consistently gathered.
#
# Given these limitations, the most important milestone that this project achieved was to build a systematic approach to understanding how Wins in MLB are created. The approach--gathering the data, cleaning it, pre-processing it, and applying a model to it-- may need to be amended or updated, but this can be followed for future projects.

# %% [markdown]
# #### <a id='10.0'><font color=black><u>10.0 Project Reflections </u></font></a>
#
# <ol>
#     <li>Baseball is personal passion of mine, and I wanted to do my Capstone project in this domain since MLB is a leader in using statistics to evaluate talent.  Also, there's a wealth of available information.</li><br />
#     <li>My goal was to make sure that my methodology to this project was sound. I made quite a few decisions that may need to be reversed, but as long as the project methdology is sound, decision changes can be easily incorporated. </li><br />
#     <li>The project took much long than planned for. Given the deadline, I wasn't able to complete the Pitching segment analysis. Most of the time was taken with the data collection and wrangling.</li><br />
#     <li>I am open to any suggestions or changes as I consider this project a first draft.</li><br />
#    </ol>

# %% [markdown]
# #### <a id='11.0'><font color=black><u>11.0 References</u></font></a>
# <ul>
#     <li>https://www.fangraphs.com/</li><br />
#     <li>https://machinelearningmastery.com</li><br />
#     <li>https://stackoverflow.com/</li><br />
#     <li>http://scikit-learn.org/stable/auto_examples/exercises/plot_cv_diabetes.html#sphx-glr-auto-examples-exercises-plot-cv-diabetes-py</li><br />
#
#   </ul>
